# %%
import json

# %%
version = 1.0
kfn_path = '../resource/'+str(version)+'/'
info_path = '../resource/info/'

# %%
def load_lus():
    fname = kfn_path+'KFN_lus.json'
    with open(fname, 'r') as f:
        lus = json.load(f)
    return lus
def load_frame2idx():
    with open(info_path+'fn1.7_frame2idx.json','r') as f:
        frame2idx = json.load(f)
    return frame2idx
lus = load_lus()
frame2idx = load_frame2idx()

# %%
def make_key(string):
    return string.replace('-', '').upper()

def gen_lu2idx():
    lu2idx = {}
    lu_items = []
    
    for luid in lus:
        lu = lus[luid]['lexeme']+'.'+lus[luid]['pos']
        lu_items.append(lu)
    lu_items = list(set(lu_items))
    lu_items.sort(key=make_key)
    
    for i in lu_items:
        lu2idx[i] = len(lu2idx)
        
    fname = info_path+'kfn'+str(version)+'_lu2idx.json'
    with open(fname, 'w') as f:
        json.dump(lu2idx, f, ensure_ascii=False, indent=4)
    print('# of lus:', len(lu_items))
    print(len(lu2idx),'is indexed to', fname)
gen_lu2idx()
# Out:
# -ㄹ_것이다.a
# 가게.n
# 가격.n
# 가계.n
# 가공.n
# 가공되다.v
# 가공하다.v
# 가까워지다.v
# 가깝다.a
# 가끔.n
# 가난.n
# 가능성.n
# 가능성있다.a
# 가능하다.a
# 가다.v
# 가담하다.v
# 가동.n
# 가동되다.v
# 가동하다.v
# 가득하다.a
# 가라앉다.v
# 가로.n
# 가로막다.v
# 가로지르다.v
# 가로채다.v
# 가르다.v
# 가르치다.v
# 가리다.v
# 가만하다.v
# 가문.n
# 가볍다.a
# 가사.n
# 가스.n
# 가슴.n
# 가운데.n
# 가위눌리다.v
# 가을.n
# 가입하다.v
# 가장.n
# 가장_아름답다.a
# 가장_우수하다.a
# 가정.n
# 가져가다.v
# 가져오다.v
# 가족.n
# 가지.n
# 가지다.v
# 가치.n
# 가치있다.a
# 가치적.n
# 각도.n
# 각성.n
# 각지.n
# 간.n
# 간격.n
# 간결하다.a
# 간주되다.v
# 간주하다.v
# 간호사.n
# 갇히다.v
# 갈기.n
# 갈다.v
# 갈래.n
# 갈망.n
# 감각.n
# 감다.a
# 감동하다.v
# 감미롭다.a
# 감사하다.a
# 감성.n
# 감소.n
# 감소되다.v
# 감소부.n
# 감소시키다.v
# 감소하다.v
# 감시.n
# 감시하다.v
# 감싸다.v
# 감안하다.v
# 감염증.n
# 감옥.n
# 감정.n
# 감지하다.v
# 감찰.n
# 감추다.v
# 감탄.n
# 감탄하다.v
# 갑종.n
# 갔다오다.v
# 강.n
# 강간자.n
# 강간하다.v
# 강력하다.a
# 강렬하다.a
# 강물.n
# 강연회.n
# 강자.n
# 강제.n
# 강조되다.v
# 강조하다.v
# 강타.n
# 강타하다.v
# 강탈되다.v
# 강하다.a
# 강화하다.v
# 갖다.v
# 갖추다.v
# 같다.a
# 개.n
# 개국.n
# 개명하다.v
# 개발.n
# 개발되다.v
# 개발중.n
# 개발하다.v
# 개방.n
# 개방하다.v
# 개선하다.v
# 개설되다.v
# 개시하다.v
# 개연성.n
# 개울.n
# 개월.n
# 개인.n
# 개인전.n
# 개입하다.v
# 개조하다.v
# 개척자.n
# 개최되다.v
# 개혁.n
# 객실.n
# 갤러리.n
# 갱신하다.v
# 거구.n
# 거대_도시.n
# 거두다.v
# 거래.n
# 거래자.n
# 거래하다.v
# 거론하다.v
# 거리.n
# 거물.n
# 거부.n
# 거부하다.v
# 거세다.a
# 거스르다.v
# 거절하다.v
# 거주민.n
# 거주자들.n
# 거주지.n
# 거주하다.v
# 거짓.n
# 거처.n
# 거치다.v
# 거칠다.a
# 거품이_일다.v
# 걱정.n
# 걱정스럽다.a
# 걱정하다.v
# 건강.n
# 건너다.v
# 건립하다.v
# 건물.n
# 건설.n
# 건설되다.v
# 건설하다.v
# 건조.n
# 건조되다.v
# 건조물.n
# 건조하다.a
# 건축.n
# 건축가.n
# 건축되다.v
# 건축물.n
# 건축하다.v
# 걷다.v
# 걸다.a
# 걸리다.v
# 걸어가다.v
# 걸어오다.v
# 걸음.n
# 걸치다.v
# 걸프.n
# 걸프전.n
# 검다.a
# 검문하다.v
# 검사.n
# 검사관들.n
# 검색되다.v
# 검은색.n
# 검증하다.v
# 검토하다.v
# 겁내다.v
# 겁먹다.v
# 것.n
# 것_같지_않다.a
# 게_되다.v
# -게_하다.a
# 게릴라.n
# 게스트.n
# 겨누다.V
# 겨자_가스.n
# 겨자가스.n
# 격감하다.v
# 격려하다.v
# 격리되다.v
# 견주다.v
# 견지하다.v
# 견해.n
# 결과.n
# 결과를_가져오다.v
# 결국.n
# 결론.n
# 결론짓다.v
# 결성되다.v
# 결성하다.v
# 결승전.n
# 결심하다.v
# 결여.n
# 결여되다.v
# 결절.n
# 결점.n
# 결정.n
# 결정되다.v
# 결정적.n
# 결정하다.a
# 결정하다.v
# 결함이_있다.a
# 결합.n
# 결합되다.v
# 결합하다.v
# 결혼.n
# 결혼자.n
# 결혼하다.v
# 겸용.n
# 겹치다.v
# 경.n
# 경계.n
# 경계하다.v
# 경관.n
# 경기.n
# 경력.n
# 경로.n
# 경매.n
# 경멸하다.v
# 경보.n
# 경비.n
# 경수로.n
# 경영자.n
# 경영하다.v
# 경외하다.v
# 경우.n
# 경쟁.n
# 경제.n
# 경제적.n
# 경찰.n
# 경향.n
# 경향이_있다.a
# 경험.n
# 계곡.n
# 계기.n
# 계단.n
# 계발.n
# 계산.n
# 계산서.n
# 계산하다.v
# 계속.ad
# 계속되다.v
# 계속하다.v
# 계시록.n
# 계약.n
# 계약하다.v
# 계획.n
# 계획하다.v
# 고.n
# -고_믿다.v
# -고_있다.a
# 고갈되다.v
# 고객.n
# 고기.n
# 고대.n
# 고도.n
# 고도화.n
# 고되다.a
# 고려.n
# 고려되다.v
# 고령화.n
# 고르다.a
# 고리.n
# 고맙다.a
# 고모.n
# 고문하다.v
# 고민.n
# 고민스럽다.a
# 고민하다.v
# 고발.n
# 고산.n
# 고생하다.v
# 고소.n
# 고소하다.a
# 고속도.n
# 고속도로.n
# 고수하다.v
# 고심.n
# 고안하다.v
# 고용.n
# 고용원들.n
# 고용하다.v
# 고위.n
# 고위공직자.n
# 고유.n
# 고유하다.a
# 고장.n
# 고전하다.v
# 고정관념.n
# 고체.n
# 고친화성.n
# 고통.n
# 고통받다.v
# 고통스럽다.a
# 고향.n
# 곡물.n
# 곤경.n
# 곤두세우다.v
# 곤란하다.a
# 곧바로.ad
# 골동품.n
# 골치가_아프다.v
# 곳.n
# 공간.n
# 공개.n
# 공개되다.v
# 공개적.n
# 공격.n
# 공격용.n
# 공격자들.n
# 공격적.n
# 공격하다.v
# 공공.n
# 공공_서비스.n
# 공공서비스.n
# 공군.n
# 공급.n
# 공급_받다.v
# 공급국.n
# 공급되다.v
# 공급자.n
# 공급자들.n
# 공급하다.v
# 공동.n
# 공동_작업하다.v
# 공동체.n
# 공무원.n
# 공물.n
# 공부하다.v
# 공세.n
# 공세적.n
# 공시하다.v
# 공약.n
# 공연.n
# 공예.n
# 공예품.n
# 공원.n
# 공장.n
# 공적.n
# 공정하다.a
# 공표하다.v
# 공항.n
# 공해.n
# 과거.n
# 과업.n
# 과외.n
# 과일.n
# 과정.n
# 과제.n
# 과학.n
# 과학자.n
# 관계.n
# 관계되다.v
# 관계자.n
# 관공서.n
# 관광.n
# 관광객.n
# 관대하다.a
# 관련.n
# 관련되다.v
# 관련있다.a
# 관련하다.v
# 관료.n
# 관리.n
# 관리되다.v
# 관리자.n
# 관리하다.v
# 관목.n
# 관습.n
# 관심.n
# 관심_가지다.v
# 관심_갖다.v
# 관심갖다.v
# 관심을_기울이다.v
# 관심이_있다.a
# 관심있다.a
# 관여.n
# 관여되다.v
# 관여하다.v
# 관찰.n
# 관찰하다.v
# 관통하다.v
# 관하다.v
# 관할하다.v
# 광경.n
# 광장.n
# 괜찮다.a
# 괴로워하다.v
# 괴롭다.a
# 괴롭히다.v
# 굉장하다.a
# 교구.n
# 교구민들.n
# 교단.n
# 교류.n
# 교류하다.v
# 교범.n
# 교사.n
# 교섭.n
# 교수님.n
# 교신하다.v
# 교원.n
# 교육.n
# 교육비.n
# 교육시키다.v
# 교장.n
# 교재.n
# 교전하다.v
# 교정.n
# 교직.n
# 교차.n
# 교체되다.v
# 교환.n
# 교환하다.v
# 교회.n
# 구간.n
# 구르다.v
# 구매.n
# 구매하다.v
# 구미.n
# 구별.n
# 구별하다.v
# 구분되다.v
# 구불하다.a
# 구비하다.v
# 구성.n
# 구성되다.v
# 구성원.n
# 구역.n
# 구입.n
# 구입하다.v
# 구조.n
# 구조물.n
# 구체적.n
# 구체화되다.v
# 구축하다.v
# 구축했다.v
# 구하다.v
# 구획되다.v
# 국가.n
# 국경.n
# 국내.n
# 국립.n
# 국립생물.n
# 국민.n
# 국방.n
# 국방부.n
# 국방전자.n
# 국어・.n
# 국제.n
# 국제적.n
# 국토안.n
# 군.n
# 군대.n
# 군림하다.v
# 군민.n
# 군사.n
# 군사력.n
# 군사용.n
# 군사적.n
# 군용.n
# 군인.n
# 군주.n
# 군중.n
# 군축.n
# 굶주리다.v
# 굶주림.n
# 굿나잇.n
# 궁극적.n
# 궁금하다.a
# 궁내성.n
# 궁정.n
# 궁지.n
# 권고.n
# 권고하다.v
# 권력.n
# 권하다.v
# 권한.n
# 궤도.n
# 궤양.n
# 귓가.n
# 규모.n
# 규정.n
# 규정되다.v
# 규제.n
# 규칙.n
# 균.n
# 균등.n
# 균주.n
# 그늘.n
# 그램.n
# 그러고_나다.v
# 그러나.ad
# 그러하다.a
# 그렇다.a
# 그려지다.v
# 그룹.n
# 그리고.ad
# 그리다.v
# 그리스.n
# 그리스인.n
# 그림.n
# 그림자.n
# 그만하다.a
# 그을리다.v
# 그자.n
# 그중.n
# 극장.n
# 극좌.n
# 근거.n
# 근로자.n
# 근무하다.v
# 근본적.n
# 근심하다.v
# 근처.n
# 글.n
# 글라스.n
# 금년.n
# 금액.n
# 금요일.n
# 금융.n
# 금주.n
# 금지.n
# 금지되다.v
# 금지하다.v
# 급.n
# 급격하다.a
# 급성장하다.v
# 급증하다.v
# 긋다.v
# 기.n
# 기간.n
# 기계.n
# 기관.n
# 기구.n
# 기기.n
# 기능.n
# 기능하다.v
# 기다.v
# 기다랗다.a
# 기다리다.v
# 기대.n
# 기대다.v
# 기대치.n
# 기대하다.v
# 기도.n
# 기도하다.v
# 기독교.n
# 기독교인.n
# 기량.n
# 기록.n
# 기록되다.v
# 기록하다.v
# 기름.n
# 기만하다.v
# 기밀이_아닌.m
# 기반.n
# 기반_시설.n
# 기별.n
# 기본.n
# 기본적.n
# 기부.n
# 기부자.n
# 기분.n
# 기분_좋다.a
# 기뻐하다.v
# 기뻐해주다.v
# 기쁘다.a
# 기사.n
# 기상.n
# 기소.n
# 기술.n
# 기술자.n
# 기술적.n
# 기술하다.v
# 기억.n
# 기억력.n
# 기억하다.v
# 기업.n
# 기업결합.n
# 기여.n
# 기여하다.v
# 기울다.v
# 기울이다.v
# 기원.n
# 기인하다.v
# 기자단.n
# 기재.n
# 기재되다.v
# 기존.n
# 기죽다.v
# 기준.n
# 기지.n
# 기지개.n
# 기차.n
# 기초.n
# 기타.n
# 기표하다.v
# 기회.n
# 기후.n
# 길.n
# 길다.a
# 길다랗다.a
# 길이.n
# -까지.j
# 깔끔하다.a
# 깜짝.ad
# 깨끗하다.a
# 깨다.v
# 깨닫다.v
# 깨어나다.v
# 깨우다.v
# 꼬임.n
# 꽃집.n
# 꿰뚫다.v
# 끈기.n
# 끊다.v
# 끌리다.v
# 끌어안다.v
# 끌어오다.v
# 끔찍스럽다.a
# 끔찍하다.a
# 끝.n
# 끝나다.v
# 끝내다.v
# 끝단.n
# 끝없다.a
# 끼다.v
# 나가다.v
# 나가버리다.v
# 나누다.v
# 나뉘다.v
# 나라.n
# 나룻.n
# 나르다.v
# 나머지.n
# 나쁘다.a
# 나서다.v
# 나아가다.v
# 나오다.v
# 나이.n
# 나중.n
# 나타나다.v
# 나타내다.v
# 낙심하다.v
# 낚시하다.v
# 낚싯대.n
# 날.n
# 날다.v
# 날렵하다.a
# 날씨.n
# 날아가다.v
# 날아오다.v
# 낡다.a
# 남.n
# 남녀.n
# 남다.v
# 남부.n
# 남북.n
# 남성.n
# 남자.n
# 남짓.n
# 남쪽.n
# 남편.n
# 납치.n
# 납치되다.v
# 납치하다.v
# 낫다.a
# 낫다.v
# 낭독.n
# 낭비하다.v
# 낮.n
# 낮다.a
# 낮추다.v
# 낳다.v
# 내.n
# 내놓다.v
# 내다.v
# 내다보다.v
# 내려가다.v
# 내려오다.v
# 내려지다.v
# 내력.n
# 내륙.n
# 내리다.v
# 내버려두다.v
# 내부.n
# 내비치다.v
# 내용.n
# 내일.n
# 내장.n
# 내적.n
# 내전.n
# 내주다.v
# 냄새.n
# 냄새나다.v
# 너머.n
# 너무.ad
# 넓다.a
# 넓이.n
# 넓히다.v
# 넘겨받다.v
# 넘다.v
# 넘어지다.v
# 넘치다.v
# 넣다.v
# 네덜란드.n
# 네델란드.n
# 네트워크.n
# 년.n
# 노구니.n
# 노년층.n
# 노동자.n
# 노래.n
# 노려보다.v
# 노력.n
# 노력하다.v
# 노심.n
# 노인.n
# 노종자.n
# 노출.n
# 노출되다.v
# 노하우.n
# 녹다.v
# 녹색.n
# 논란.n
# 논의.n
# 논의되다.v
# 논의하다.v
# 논쟁.n
# 논평.n
# 놀라다.v
# 놀랍다.a
# 농공용.n
# 농부.n
# 농업용.n
# 농장.n
# 농촌.n
# 농축.n
# 농축시키다.v
# 농축하다.v
# 높다.a
# 높이.n
# 높이다.v
# 놓다.v
# 놓이다.v
# 놓치다.v
# 뇌리.n
# 누그러들다.v
# 누르다.a
# 눅눅하다.a
# 눈.n
# 눈길.n
# 눈뜨다.v
# 눈빛.n
# 눈썹.n
# 눈알.n
# 눈여겨보다.v
# 눈치채다.v
# 뉘우침.n
# 느껴지다.v
# 느끼다.v
# 느낌.n
# 느리다.a
# 늘.ad
# 늘어나다.v
# 늙다.v
# 늙은이.n
# 능력.n
# 다니다.v
# 다다르다.v
# 다량.n
# 다루다.v
# 다룸.n
# 다르다.a
# 다리.n
# 다발.n
# 다방면.n
# 다수.n
# 다스리다.v
# 다양하다.a
# 다음.n
# 다이나마이트.n
# 다이비루.n
# 다치다.v
# 다툼.n
# 다하다.v
# 다행.n
# 단가.n
# 단계.n
# 단어.n
# 단원.n
# 단일.n
# 단장.n
# 단지.n
# 단체.n
# 단체전.n
# 단축하다.v
# 단품.n
# 단품별.n
# 닫히다.v
# 달.n
# 달갑다.a
# 달다.a
# 달라지다.v
# 달려가다.v
# 달려오다.v
# 달리.ad
# 달리다.v
# 달성되다.v
# 달성하다.v
# 달아나다.v
# 달하다.v
# 닮다.v
# 담당.n
# 담당하다.v
# 담배.n
# 담소.n
# 답변하다.v
# 당.n
# 당국.n
# 당국자.n
# 당기다.v
# 당당하다.a
# 당사국.n
# 당사자.n
# 당선.v
# 당선되다.v
# 당황하다.v
# 당회.n
# 닿다.v
# 대.n
# 대가.n
# 대결.n
# 대다.v
# 대담.n
# 대량_살상_무기.n
# 대량_파괴_무기.n
# 대로.n
# 대륙간_탄도_미사일.n
# 대리.n
# 대비하다.v
# 대상.n
# 대실패.n
# 대용품.n
# 대응책.n
# 대응하다.v
# 대입시키다.v
# 대전.n
# 대중.n
# 대지.n
# 대체.n
# 대체되다.v
# 대체하다.v
# 대치.n
# 대치하다.v
# 대통령.n
# 대포.n
# 대표.n
# 대표자.n
# 대피.n
# 대하다.v
# 대학.n
# 대학원.n
# 대한.n
# 대형.n
# 대화.n
# 대화하다.v
# 대회.n
# 더.ad
# 더_강력하다.a
# 더_많다.a
# 더_쉽다.a
# 더_어렵다.a
# 더_엄격하다.a
# 더_오래되다.a
# 더_이상.ad
# 더_좋다.a
# 더_폭넓다.a
# 더_풍요롭다.a
# 더듬다.v
# 더미.n
# 더블린인.n
# 더하다.a
# 덕분.n
# 던지다.v
# 덜.ad
# 덥다.a
# 덮이다.v
# 데려가다.v
# 데려오다.v
# 데리다.v
# 데이터.n
# 도구.n
# 도난.n
# 도난당하다.v
# 도달하다.a
# 도둑.n
# 도둑맞다.v
# 도로.n
# -도록_하다.v
# 도망가다.v
# 도망치다.v
# 도무지.ad
# 도민.n
# 도박장들.n
# 도보거리.n
# 도서관.n
# 도시.n
# 도어.n
# 도와주다.v
# 도움.n
# 도입.n
# 도전.n
# 도착.n
# 도착하다.v
# 도처.n
# 독.n
# 독감.n
# 독립.n
# 독립하다.v
# 독서.n
# 독서실.n
# 독성.n
# 독성이_있다.a
# 독소.n
# 독약.n
# 독일.n
# 독일인들.n
# 독자.n
# 독특하다.a
# 독하다.a
# 돈.n
# 돌다.v
# 돌려받다.v
# 돌리다.v
# 돌보다.v
# 돌아가다.v
# 돌아다니다.v
# 돌아오다.v
# 돕다.v
# 동.n
# 동감하다.v
# 동거.n
# 동거인.n
# 동결.n
# 동결시키다.v
# 동결하다.v
# 동경.n
# 동굴.n
# 동기.n
# 동년배.n
# 동력.n
# 동력용.n
# 동료.n
# 동맹.n
# 동물원.n
# 동반자.n
# 동반하다.v
# 동봉하다.v
# 동부.n
# 동생.n
# 동시.n
# 동식물원.n
# 동안.n
# 동원하다.v
# 동의.n
# 동의하다.v
# 동일.n
# 동쪽.n
# 되다.a
# 되돌리다.v
# 되짚다.v
# 두다.v
# 두드러지다.a
# 두들기다.v
# 두려워하다.v
# 두렵다.a
# 두목.n
# 두바이.n
# 둘러보다.v
# 둘러싸다.v
# 둘레.n
# 뒤.n
# 뒤덮이다.v
# 뒤돌다.v
# 뒤돌아보다.v
# 뒤잇다.v
# 뒤지다.v
# 뒤쫓다.v
# 뒷정리.n
# 드나들다.v
# 드라마.n
# 드러나다.v
# 드러내다.v
# 드리우다.v
# 드물다.a
# 듣다.v
# 들다.v
# 들려주다.v
# 들리다.v
# 들어가다.v
# 들어보다.v
# 들어오다.v
# 들어주다.v
# 들여다보다.v
# 들판.n
# 듯.n
# 등.n
# 등극.n
# 등반하다.v
# 등산.n
# 등산가들.n
# 디자인.n
# 따뜻하다.a
# 따뜻해지다.v
# 따라가다.v
# 따라나서다.v
# 따라서.ad
# 따르다.v
# 딸.n
# 땀.n
# 땅.n
# 때.n
# 때문.n
# 떠나다.v
# 떠름하다.a
# 떠맡다.v
# 떠오르다.v
# 떠올리다.v
# 떨다.v
# 떨어뜨리다.v
# 떨어지다.v
# 떼.n
# 떼다.v
# 똑똑하다.a
# 뚜렷하다.a
# 뚫리다.v
# 뛰다.v
# 뛰어넘다.v
# 뛰어들다.v
# 뜨거워하다.v
# 뜨겁다.a
# 뜨다.a
# 뜯다.v
# 뜰.n
# 뜻.n
# 뜻하다.v
# 띠.n
# -라고_믿다.v
# 라디오.n
# 라이선스.n
# 량.n
# 러시아.n
# 레스토랑.n
# 레이더.n
# -려_하다.a
# -려고_하다.v
# 로비.n
# 로켓.n
# 루트.n
# 루푸.n
# 루프.n
# 리더.n
# 리드미컬하다.a
# 리듬.n
# 리비아.n
# -마다.j
# 마련하다.v
# 마루.n
# 마르다.v
# 마마.n
# 마스터하다.v
# 마시다.v
# 마약.n
# 마요네스.n
# 마을.n
# 마을_이름.n
# 마음.n
# 마음이_흐트러지다.v
# 마일.n
# 마주보다.v
# 마지막.n
# 마치다.v
# 마침내.ad
# 막다.v
# 막부.n
# 막사.n
# 막중하다.a
# 막히다.v
# 만.n
# 만곡.n
# 만나다.v
# 만들다.v
# 만들어내다.v
# 만들어주다.v
# 만들어지다.v
# 만성.n
# 만연하다.a
# 만족하다.v
# 만지다.v
# 만하다.a
# 만하다.v
# 많다.a
# 말.n
# 말기.n
# 말들.n
# 말을_걸다.v
# 말하다.v
# 말해주다.v
# 맑다.a
# 맘마.n
# 맛.n
# 맛보다.v
# 맛있다.a
# 망.n
# 망가뜨리다.v
# 망명하다.v
# 맞다.v
# 맞바꾸다.v
# 맞서다.v
# 맞추다.v
# 맡다.v
# 매.n
# 매뉴얼.n
# 매달.n
# 매달리다.v
# 매도하다.v
# 매력.n
# 매립지.n
# 매복.n
# 매일.n
# 매혹시키다.v
# 맹세하다.v
# 맺다.v
# 머리.n
# 머무르다.v
# 머물다.v
# 먹다.v
# 먹이다.v
# 멀다.a
# 멀리.n
# 멈추다.v
# 멋지다.a
# 메시지.n
# 멤버.n
# 멤버국들.n
# 멤버십.n
# 며칠.n
# 면.n
# 면허.n
# 멸망시키다.v
# 명.n
# 명령.n
# 명령받다.v
# 명령하다.v
# 명명되다.v
# 명명하다.v
# 명분.n
# 명성을_얻다.v
# 명소.n
# 명절.n
# 명칭.n
# 명확하다.a
# 모깃소리.n
# 모델.n
# 모두.n
# 모래.n
# 모르다.v
# 모면하다.v
# 모색하다.v
# 모순되다.v
# 모스크.n
# 모습.n
# 모양.n
# 모양새.n
# 모여들다.v
# 모욕.n
# 모이다.v
# 모임.n
# 모텔.n
# 모퉁이.n
# 모험.n
# 모형.n
# 모호하다.a
# 목.n
# 목격하다.v
# 목록.n
# 목사.n
# 목요일.n
# 목장.n
# 목적.n
# 목표.n
# 몰.n
# 몰다.v
# 몰몬.n
# 몸.n
# 몸담다.v
# 못하다.a
# 묘사되다.v
# 묘사하다.v
# 무겁다.a
# 무게.n
# 무고하다.a
# 무기.n
# 무기급.n
# 무기류.n
# 무기화.n
# 무능력.n
# 무덥다.a
# 무료.n
# 무사.n
# 무슬림.n
# 무슬림_형제단.n
# 무슬림들.n
# 무엇하다.a
# 무역.n
# 무장_강도.n
# 무장되다.v
# 무장하다.v
# 무지.n
# 묵다.v
# 묶다.v
# 문.n
# 문밖.n
# 문서.n
# 문언.n
# 문제.n
# 문학.n
# 문호.n
# 문화.n
# 문화원.n
# 문화적.n
# 묻다.v
# 물.n
# 물건.n
# 물결.n
# 물다.v
# 물러나다.v
# 물질.n
# 미국.n
# 미국인.n
# 미군.n
# 미끄러지다.v
# 미끼.n
# 미래.n
# 미리.ad
# 미사일.n
# 미소.n
# 미숙하다.a
# 미술가들.n
# 미움.n
# 미워하다.v
# 미터.n
# 미터톤.n
# 미팅.n
# 민간용.n
# 믿다.v
# 믿어지다.v
# 믿음.n
# 밀거래자.n
# 밀다.v
# 밀려나다.v
# 밀려오다.v
# 밀리미터.n
# 밀반입하다.v
# 밀재자들.n
# 밀접하다.a
# 밑.n
# 바.n
# 바꾸다.v
# 바뀌다.v
# 바다.n
# 바닥.n
# 바닷가.n
# 바닷쪽.n
# 바라다.v
# 바라보다.v
# 바람.n
# 바람직하다.a
# 바르다.a
# 바쁘다.a
# 바퀴.n
# 바탕.n
# 박다.v
# 박물관.n
# 박수.n
# 박스테이프.n
# 박탈하다.v
# 밖.n
# 반.n
# 반감.n
# 반기.n
# 반대.n
# 반대하다.v
# 반더포겔부.n
# 반도.n
# 반란.n
# 반복되다.v
# 반성.n
# 반세기.n
# 반응.n
# 반응기.n
# 반응하다.v
# 반증하다.v
# 반짝이다.v
# 반하다.v
# 받다.v
# 받아_챙기다.v
# 받아들다.v
# 받아들이다.v
# 발.n
# 발견.n
# 발견되다.v
# 발견하다.v
# 발달.n
# 발달하다.v
# 발명.n
# 발명하다.v
# 발사.n
# 발사되다.v
# 발사체.n
# 발사하다.v
# 발산되다.v
# 발생시키다.v
# 발생하다.v
# 발언하다.v
# 발전.n
# 발전되다.v
# 발전소.n
# 발전시키다.v
# 발전하다.v
# 발족하다.v
# 발주.n
# 발주하다.v
# 발표.n
# 발표하다.v
# 발하다.v
# 발행.n
# 발행하다.v
# 발휘.n
# 밝혀지다.v
# 밝히다.v
# 밟다.v
# 밤.n
# 밤낮.n
# 밤새.n
# 밤잠.n
# 밤중.n
# 밧줄.n
# 방.n
# 방들.n
# 방면하다.v
# 방문.n
# 방문자.n
# 방문자들.n
# 방문하다.v
# 방법.n
# 방법론.n
# 방벽.n
# 방식.n
# 방안.n
# 방어.n
# 방어자들.n
# 방어적.n
# 방어진지.n
# 방어하다.v
# 방위.n
# 방지.n
# 방출.n
# 방해.n
# 방해_행위.n
# 방해되다.v
# 방해받다.v
# 밭.n
# 배.n
# 배달되다.v
# 배달하다.v
# 배당되다.v
# 배들.n
# 배럴.n
# 배려.n
# 배분.n
# 배상.n
# 배우다.v
# 배움.n
# 배웅하다.v
# 배출하다.v
# 배치.n
# 배치되다.v
# 배치하다.v
# 배포.n
# 배포되다.v
# 배포하다.v
# 배회하다.v
# 백명산.n
# 백문.n
# 백성.n
# 백악관.n
# 백톤.n
# 뱉다.v
# 버리다.v
# 버스.n
# 버전.n
# 번성하다.v
# 번영.n
# 번창하다.v
# 벌게지다.v
# 벌다.v
# 벌리다.v
# 벌을_주다.v
# 범선.n
# 범위.n
# 범죄.n
# 범행.n
# 법.n
# 법관.n
# 법률가.n
# 법원.n
# 법정.n
# 법칙.n
# 벗다.v
# 벗어나다.v
# 벽.n
# 벽들.n
# 변경.n
# 변경시키다.v
# 변덕스럽다.a
# 변수.n
# 변신.n
# 변종.n
# 변하다.v
# 변형.n
# 변형하다.v
# 변호사.n
# 변화.n
# 변화시키다.v
# 변화하다.v
# 별개.n
# 별명.n
# 별원.n
# 병.n
# 병기고.n
# 병력.n
# 병원.n
# 보건.n
# 보고.n
# 보고되다.v
# 보고서.n
# 보고하다.v
# 보급.n
# 보급국.n
# 보급자.n
# 보급자들.n
# 보급품.n
# 보급하다.v
# 보내다.v
# 보내지다.v
# -보다.j
# 보다.v
# 보도.n
# 보도되다.v
# 보도하다.v
# 보류하다.v
# 보병.n
# 보복.n
# 보복하다.v
# 보상.n
# 보안.n
# 보여주다.v
# 보완되다.v
# 보완하다.v
# 보유.n
# 보유국들.n
# 보유하다.v
# 보이다.v
# 보장되다.v
# 보장하다.v
# 보존.n
# 보충수.n
# 보트.n
# 보호.n
# 보호되다.v
# 보호받다.v
# 보호복.n
# 보호책.n
# 보호하다.v
# 복귀.n
# 복원되다.v
# 복잡하다.a
# 복제품.n
# 복합.n
# 복합화.n
# 본거지.n
# 본국.n
# 본보기.n
# 본부.n
# 본전.n
# 본토.n
# 봄.n
# 봉기.n
# 봉기하다.v
# 봉사.n
# 봉사하다.v
# 봉인.n
# 봉투.n
# 봐주다.v
# 부끄럽다.a
# 부당하다.a
# 부대.n
# 부드럽다.a
# 부딪히다.v
# 부류.n
# 부르다.v
# 부르짖다.v
# 부름.n
# 부모.n
# 부문.n
# 부문별.n
# 부분.n
# 부산만.n
# 부상.n
# 부상당하다.v
# 부상하다.v
# 부서.n
# 부서지다.v
# 부속.n
# 부수다.v
# 부술.n
# 부양하다.v
# 부엌.n
# 부여하다.v
# 부원.n
# 부위.n
# 부인.n
# 부인되다.v
# 부인하다.v
# 부적합하다.a
# 부정하다.a
# 부정확하다.a
# 부족.n
# 부족하다.a
# 부착되다.v
# 부츠.n
# 부탁하다.v
# 부패하다.v
# 부품.n
# 부하.n
# 부활시키다.v
# 북.n
# 북부.n
# 북쪽.n
# 북쪽_부분.n
# 북한.n
# 분.n
# 분간.n
# 분기.n
# 분노하다.v
# 분들.n
# 분류되다.v
# 분류하다.v
# 분리.n
# 분리되다.v
# 분명하다.a
# 분무.n
# 분석.n
# 분석가.n
# 분석가들.n
# 분석하다.v
# 분야.n
# 분연하다.a
# 분쟁.n
# 분주하다.a
# 분지.n
# 분출되다.v
# 분할.n
# 분화.n
# 분화・.n
# 분화하다.v
# 불러오다.v
# 불륜.n
# 불리다.v
# 불만.n
# 불만족스럽다.a
# 불만족하다.v
# 불명확하다.a
# 불법.n
# 불법_거래자.n
# 불법적.n
# 불법화되다.v
# 불법화하다.v
# 불분명하다.a
# 불시.n
# 불안감.n
# 불충분.n
# 불평.n
# 불행.n
# 불화.n
# 불확실하다.a
# 붉다.a
# 붉어지다.v
# 붉히다.v
# 붐비다.v
# 붙다.v
# 붙이다.v
# 블록.n
# 비.n
# 비결.n
# 비결임.n
# 비교하다.v
# 비극.n
# 비길_데가_없다.a
# 비난_받다.v
# 비난받다.v
# 비난하다.v
# 비다.a
# 비롯되다.v
# 비롯하다.v
# 비밀.n
# 비밀리.n
# 비밀스럽다.a
# 비밀회.n
# 비스듬하다.a
# 비슷비슷하다.a
# 비슷하다.a
# 비싸다.a
# 비용.n
# 비우다.v
# 비유되다.v
# 비준.n
# 비준하다.v
# 비추다.v
# 비축.n
# 비축되다.v
# 비축물.n
# 비축하다.v
# 비치다.v
# 비토착민.n
# 비통해_하다.v
# 비트.n
# 비판적.n
# 비평가.n
# 비평하다.v
# 비하다.v
# 비행.n
# 비행기.n
# 비행시험.n
# 비행장.n
# 비행체.n
# 비행하다.v
# 빈곤.n
# 빈번하다.a
# 빈집.n
# 빌딩.n
# 빗다.v
# 빗발.n
# 빙하.n
# 빛.n
# 빠뜨리다.v
# 빠르다.a
# 빠져나가다.v
# 빠져들다.v
# 빠지다.v
# 빨갛다.a
# 빨개지다.v
# 빨리.ad
# 빼앗다.v
# 뻔뻔하다.a
# 뻗다.v
# 뻗치다.v
# 삐지다.v
# 사.n
# 사건.n
# 사고.n
# 사내.n
# 사냥하다.v
# 사다.v
# 사들이다.v
# 사라지다.v
# 사람.n
# 사랑.n
# 사랑받다.v
# 사랑하는_자식.n
# 사랑하다.v
# 사러가다.v
# 사령관.n
# 사례.n
# 사막.n
# 사망.n
# 사망률.n
# 사망하다.v
# 사무실.n
# 사백.n
# 사보타주.n
# 사살.n
# 사살되다.v
# 사살하다.v
# 사상.n
# 사상・.n
# 사상자.n
# 사설.n
# 사소하다.a
# 사실.n
# 사악하다.a
# 사안.n
# 사양하다.v
# 사업.n
# 사업소.n
# 사업용.n
# 사업체.n
# 사용.n
# 사용되다.v
# 사용하다.v
# 사원.n
# 사이.n
# 사이트.n
# 사일로.n
# 사장.n
# 사장되다.v
# 사정.n
# 사진.n
# 사찰.n
# 사찰하다.v
# 사항.n
# 사형장.n
# 사형하다.v
# 사회.n
# 사회_기반_시설.n
# 사회적.n
# 사후.n
# 삭감.n
# 삭주시.n
# 산.n
# 산들.n
# 산발적.n
# 산악부.n
# 산업.n
# 산업용.n
# 산업화.n
# 산장.n
# 산책하다.v
# 산호.n
# 살.n
# 살다.v
# 살상.n
# 살아가다.v
# 살아나다.v
# 살인.n
# 살인사건.n
# 살인자.n
# 살지다.a
# 살펴보다.v
# 살포.n
# 살포하다.v
# 살피다.a
# 살해.n
# 살해되다.v
# 살해하다.v
# 삼백.n
# 삼분.n
# 삼촌.n
# 상.n
# 상공.n
# 상관.n
# 상관없다.a
# 상기시키다.v
# 상담.n
# 상당.n
# 상당하다.a
# 상대.n
# 상대하다.v
# 상법.n
# 상상하다.v
# 상순.n
# 상원.n
# 상위.n
# 상의하다.v
# 상점.n
# 상징하다.v
# 상처.n
# 상충하다.v
# 상태.n
# 상태이다.a
# 상품.n
# 상해율.n
# 새것.n
# 새까맣다.a
# 새롭다.a
# 새콤달콤하다.a
# 색다르다.a
# 색소.n
# 샘.n
# 샘들.n
# 생각.n
# 생각나다.v
# 생각되다.v
# 생각에_잠기다.v
# 생각하다.v
# 생겨나다.v
# 생기다.v
# 생명.n
# 생명_공학.n
# 생명공학.n
# 생물.n
# 생물_무기.n
# 생물_테러리스트.n
# 생물_테러리즘.n
# 생물전.n
# 생물학.n
# 생물학_무기.n
# 생물학_테러.n
# 생물학무기.n
# 생물학적.n
# 생산.n
# 생산되다.v
# 생산하다.v
# 생선.n
# 생성.n
# 생활하다.v
# 서.n
# 서다.v
# 서두.n
# 서두르다.v
# 서명.n
# 서명하다.v
# 서부.n
# 서비스.n
# 서사시.n
# 서생.n
# 서술하다.v
# 서약.n
# 서약하다.v
# 서양.n
# 서적.n
# 서점.n
# 서쪽.n
# 서플라이어.n
# 서한.n
# 선.n
# 선거.n
# 선고되다.v
# 선고하다.v
# 선도.n
# 선로.n
# 선명하다.a
# 선물.n
# 선박.n
# 선사시대.n
# 선생.n
# 선생님.n
# 선수.n
# 선술집.n
# 선언.n
# 선언서.n
# 선언하다.v
# 선임.n
# 선적.n
# 선적하다.v
# 선정.n
# 선정되다.v
# 선정하다.v
# 선조.n
# 선진.n
# 선진국.n
# 선출되다.v
# 선택하다.v
# 선포하다.v
# 선행하다.v
# 선향.n
# 선호하다.v
# 설계.n
# 설계되다.v
# 설계하다.v
# 설득하다.v
# 설립.n
# 설립되다.v
# 설립하다.v
# 설명.n
# 설명하다.v
# 설정하다.v
# 설치하다.v
# 설탕.n
# 섬.n
# 섬_전체.n
# 섬들.n
# 성.n
# 성경.n
# 성공.n
# 성공적이지_못하다.a
# 성공하다.v
# 성과.n
# 성능.n
# 성대하다.a
# 성도.n
# 성명.n
# 성벽.n
# 성분.n
# 성인.n
# 성장.n
# 성장하다.v
# 성전.n
# 성채.n
# 성취감을_주다.v
# 성취하다.v
# 성향.n
# 성황.n
# 세.n
# 세계.n
# 세계적.n
# 세관원들.n
# 세균전.n
# 세기.n
# 세단.n
# 세대.n
# 세력.n
# 세례.n
# 세로.n
# 세미나.n
# 세부내용.n
# 세상.n
# 세우다.v
# 세일즈.n
# 세포성.n
# 센터.n
# 센티미터.n
# 셋집.n
# 소나기.n
# 소녀.n
# 소년.n
# 소득.n
# 소량.n
# 소리.n
# 소리치다.v
# 소멸하다.v
# 소모되다.v
# 소문.n
# 소문나다.v
# 소비에트.n
# 소설.n
# 소속되다.v
# 소송.n
# 소수.n
# 소식통.n
# 소실되다.v
# 소용없다.a
# 소유.n
# 소유권.n
# 소유되다.v
# 소유자.n
# 소유하다.v
# 소장품.n
# 소장하다.v
# 소지품.n
# 소풍.n
# 소형.n
# 속.n
# 속도.n
# 속력.n
# 속마음.n
# 속이다.v
# 속하다.a
# 속하다.v
# 손.n
# 손가락.n
# 손사래.n
# 손실.n
# 손쓰다.v
# 손에_넣다.v
# 손을_내밀다.v
# 손익.n
# 손해.n
# 솔직성.n
# 솔직하다.a
# 솟아나다.v
# 송구스럽다.a
# 송전.n
# 쇠퇴하다.v
# 쇼핑.n
# 수.n
# 수_세기.n
# 수_없다.a
# 수_있다.a
# 수_있다.v
# 수감하다.v
# 수고.n
# 수고롭다.a
# 수년.n
# 수다.n
# 수단.n
# 수도.n
# 수도권.n
# 수도원.n
# 수레.n
# 수령하다.v
# 수로.n
# 수립.n
# 수립되다.v
# 수립하다.v
# 수많다.a
# 수반.n
# 수백.n
# 수백만.n
# 수상.n
# 수상기.n
# 수상자.n
# 수송.n
# 수송하다.v
# 수업.n
# 수영하다.v
# 수요.n
# 수익.n
# 수입.n
# 수입되다.v
# 수입품.n
# 수입하다.v
# 수장.n
# 수장품.n
# 수정하다.v
# 수준.n
# 수준_높다.a
# 수집하다.v
# 수-천.n
# 수천.n
# 수첩.n
# 수출.n
# 수출되다.v
# 수출자들.n
# 수출하다.v
# 수치스럽다.a
# 수포.n
# 수학・.n
# 수행되다.v
# 수행하다.v
# 수확.n
# 숙련되다.v
# 숙소.n
# 순간.n
# 순례하다.v
# 순이익.n
# 술집.n
# 숨.n
# 숨다.v
# 숫자.n
# 숲.n
# 쉬다.v
# 쉽다.a
# 스승.n
# 스치다.v
# 스커드-B_미사일.n
# 스커드-C_미사일.n
# 스타.n
# 스타일.n
# 스피드.n
# 슬쩍하다.v
# 슬퍼하다.v
# 슬프다.a
# 습격.n
# 습격하다.v
# 습하다.a
# 승리.n
# 승리자들.n
# 승리하다.v
# 승무원.n
# 승인.n
# 승인되다.v
# 승인하다.v
# 승천하다.v
# 시.n
# 시간.n
# 시계.n
# 시골.n
# 시골_지역.n
# 시기.n
# 시끄럽다.a
# 시내.n
# 시달리다.v
# 시대.n
# 시도.n
# 시도하다.v
# 시리아.n
# 시민.n
# 시사하다.v
# 시선.n
# 시설.n
# 시술하다.v
# 시스템.n
# 시야.n
# 시원하다.a
# 시의.n
# 시인하다.v
# 시작.n
# 시작되다.v
# 시작하다.v
# 시장.n
# 시청.n
# 시청하다.v
# 시합.n
# 시행.n
# 시행하다.v
# 시험.n
# 시험소.n
# 시험장.n
# 시험하다.v
# 식당.n
# 식량.n
# 식민지.n
# 식사.n
# 식품.n
# 신경.n
# 신경질적.n
# 신고.n
# 신기하다.a
# 신념.n
# 신념적.n
# 신도.n
# 신령.n
# 신뢰.n
# 신뢰받다.v
# 신문.n
# 신봉.n
# 신빙성.n
# 신사.n
# 신선란.n
# 신속하다.a
# 신입.n
# 신장시키다.v
# 신전.n
# 신조.n
# 신중하다.a
# 신청하다.v
# 신체.n
# 신학.n
# 신형.n
# 신호.n
# 실력.n
# 실례.n
# 실리.n
# 실리다.v
# 실망하다.v
# 실수.n
# 실시되다.v
# 실업률.n
# 실적.n
# 실정.n
# 실제.n
# 실존.n
# 실직하다.v
# 실태.n
# 실패.n
# 실패하다.v
# 실행.n
# 실행되다.v
# 실행하다.v
# 실험.n
# 실험소.n
# 실험실.n
# 실험하다.v
# 실현.n
# 실현하다.v
# 싫증.n
# 심각하다.a
# 심기.n
# 심하다.a
# 십자가_처형.n
# 십자가형.n
# 싶다.v
# 싶어하다.v
# 싸우다.v
# 싸움.n
# 쌓이다.v
# 썩다.v
# 쏘아보다.v
# 쏟아지다.v
# 쑥덕공론.n
# 쓰다.a
# 쓰라리다.a
# 쓰러뜨리다.v
# 쓰이다.v
# 아내.n
# 아늑하다.a
# 아니하다.a
# 아담하다.a
# 아동.n
# 아들.n
# 아래.n
# 아름답다.a
# 아마추어.n
# 아무도.ad
# 아버지.n
# -아보다.e
# 아빠.n
# 아이.n
# 아일랜드.n
# 아일랜드_사람.n
# 아침.n
# 아트로핀.n
# 아파트.n
# 아프게_하다.v
# 아프다.a
# 악화되다.v
# 악화시키다.v
# 안.n
# 안개.n
# 안건.n
# 안내.n
# 안내인.n
# 안내하다.v
# 안다.v
# 안달하다.v
# 안되다.a
# 안보.n
# 안심시키다.v
# 안전.n
# 안전하다.a
# 안정.n
# 안정되다.v
# 안쪽.n
# 앉다.v
# 않다.a
# 알게_되다.v
# 알다.v
# 알다시피.ad
# 알려지다.v
# 알루미늄.n
# 알리다.v
# 알선자.n
# 알아가다.v
# 알아내다.v
# 알아보다.v
# 알아채다.v
# 알코올.n
# 암.n
# 암살.n
# 암살하다.v
# 암시.n
# 암시하다.v
# 암흑.n
# 암흑시대.n
# 압력.n
# 압류되다.v
# 압박하다.v
# 압수되다.v
# 압수하다.v
# 앗다.v
# 앞.n
# 앞두다.v
# 애당초.n
# 애도하다.v
# 애쓰다.v
# 애인.n
# 애정.n
# 애초.n
# 액체.n
# 야.n
# -야_하다.a
# -야_하다.v
# 야_하다.v
# 야기시키다.v
# 야당.n
# 야망.n
# 야외_공간.n
# 약간.n
# 약국.n
# 약사.n
# 약속.n
# 약속하다.v
# 약초.n
# 약혼자.n
# 약화되다.v
# 양.n
# 양보하다.v
# 양용.n
# 양항.n
# 얘기하다.v
# 어.n
# 어두움.n
# 어떤.m
# 어려움.n
# 어려워지다.v
# 어렵다.a
# 어루만지다.v
# 어른.n
# 어리다.a
# 어리둥절하다.a
# 어린아이.n
# 어린이.n
# 어머니.n
# 어부.n
# 어울리다.v
# 어원.n
# 어이없다.a
# 어제.n
# 억제하다.v
# 언급.n
# 언급되다.v
# 언급하다.v
# 언덕.n
# 언명하다.v
# 언짢다.a
# 얻다.v
# 얻어지다.v
# 얼굴.n
# 얼마.ad
# 얼마.n
# 엄격하다.a
# 엄마.n
# 엄청나다.a
# 업무.n
# 업적.n
# 없다.a
# 없어지다.v
# 엇나가다.v
# 엉덩이.n
# 엉터리_예술가.n
# -에 대하다.mwe
# 에.j
# -에.j
# -에_따르다.v
# 에너지.n
# -에는.j
# 에는.j
# 에다.v
# 에스컬레이터.n
# 에이전트.n
# 에이커.n
# 에이크.n
# 엔진.n
# 엘리베이터.n
# 여겨지다.v
# 여권.n
# 여기다.v
# 여론.n
# 여름.n
# 여성.n
# 여왕.n
# 여인.n
# 여자.n
# 여정.n
# 여지.n
# 여행.n
# 여행자.n
# 여행하다.v
# 역.n
# 역겹다.a
# 역량.n
# 역사.n
# 역사상.n
# 역사적.n
# 역점.n
# 역할.n
# 역할을_하다.v
# 연결되다.v
# 연결하다.v
# 연계.n
# 연계되다.v
# 연구.n
# 연구단.n
# 연구용.n
# 연구원.n
# 연구하다.a
# 연구회.n
# 연기하다.v
# 연락선.n
# 연령.n
# 연례.n
# 연루되다.v
# 연맹.n
# 연방.n
# 연방정부.n
# 연설.n
# 연설하다.v
# 연안.n
# 연애.n
# 연인.n
# 연장하다.v
# 연주하다.v
# 연합.n
# 연회.n
# 열다.v
# 열리다.v
# 열망.n
# 열쇠.n
# 열핵무기.n
# 염려.n
# 염려되다.v
# 염려스럽다.a
# 염려하다.a
# 염좌.n
# 엿보다.v
# 영국인.n
# 영국인들.n
# 영양실조.n
# 영업력.n
# 영역.n
# 영토.n
# 영하.n
# 영향.n
# 영향_받다.v
# 영향력.n
# 영향받다.v
# 영향을_미치다.v
# 영향을_주다.v
# 옆.n
# 예.n
# 예고하다.v
# 예들.n
# 예방하다.v
# 예배.n
# 예배소.n
# 예산.n
# 예상.n
# 예상_밖의.m
# 예상되다.v
# 예상하다.v
# 예선.n
# 예술.n
# 예술가.n
# 예언.n
# 예측.n
# 예측되다.v
# 예측량.n
# 예측하다.v
# 예측할_수_없다.a
# 옛날.n
# 오너.n
# 오늘.n
# 오다.v
# 오락.n
# 오락적.n
# 오래.ad
# 오래되다.a
# 오랫동안.n
# 오르다.v
# 오르락내리락.ad
# 오사카병원.n
# 오야마.n
# 오일.n
# 오토.n
# 오후.n
# 온도.n
# 온실.n
# 올라가다.v
# 올라오다.v
# 올라타다.v
# 올려놓다.v
# 올려다보다.v
# 올리다.v
# 올바르다.a
# 올해.n
# 옮겨지다.v
# 옮기다.v
# 옮다.v
# 옳다.a
# 옷.n
# 옹호하다.v
# 와중.n
# 왁자지껄하다.a
# 완공.n
# 완공되다.v
# 완공하다.v
# 완료.n
# 완료되다.v
# 완료하다.v
# 완성되다.v
# 완성하다.v
# 완수하다.v
# 완전.n
# 완화하다.v
# 왈츠.n
# 왕국.n
# 왕궁.n
# 왕조.n
# 왕진.n
# 외견상.n
# 외곽.n
# 외국.n
# 외국인.n
# 외딴.n
# 외무.n
# 외부.n
# 외부적.n
# 외상.n
# 외출하다.v
# 왼편.n
# 요강.n
# 요건.n
# 요구.n
# 요구되다.v
# 요구하다.v
# 요리하다.v
# 요새.n
# 요새화.n
# 요새화하다.v
# 요소.n
# 요약하다.v
# 요원.n
# 요점.n
# 요청.n
# 요청_받다.v
# 요청받다.v
# 요청하다.v
# 욕구.n
# 욕설.n
# 용기.n
# 용도.n
# 용량.n
# 용서.n
# 용서받다.v
# 용서하다.v
# 용어.n
# 용접하다.v
# 우견.n
# 우두머리.n
# 우라늄.n
# 우려.n
# 우려하다.v
# 우림.n
# 우아하다.a
# 우체국.n
# 우편.n
# 운.n
# 운명.n
# 운반.n
# 운반하다.v
# 운송.n
# 운영.n
# 운영비.n
# 운용.n
# 운전하다.v
# 운하.n
# 울다.v
# 울려나오다.v
# 울리다.v
# 울부짖다.v
# 울음.n
# 움직이다.v
# 웃다.v
# 웅장하다.a
# 워크숍.n
# 원.n
# 원서.n
# 원심_분리기.n
# 원심분리기.n
# 원양.n
# 원인.n
# 원인이_되다.v
# 원인임.n
# 원자.n
# 원자_폭탄.n
# 원자력.n
# 원자로.n
# 원자로급.n
# 원장.n
# 원조.n
# 원천.n
# 원하다.v
# 월.n
# 월요일.n
# 위.n
# 위기.n
# 위대하다.a
# 위반.n
# 위생.n
# 위생계.n
# 위자료.n
# 위장.n
# 위축되다.v
# 위치.n
# 위치시키다.v
# 위치하다.v
# 위태롭게_만들다.v
# 위하다.v
# 위험.n
# 위협.n
# 위협하다.v
# 유감.n
# 유감스럽게_생각하다.v
# 유감스럽다.a
# 유능하다.a
# 유니폼.n
# 유대.n
# 유대인.n
# 유도인.n
# 유독.n
# 유독하다.a
# 유동화하다.v
# 유람선.n
# 유래.n
# 유래되다.v
# 유럽.n
# 유력하다.a
# 유리하다.a
# 유망하다.a
# 유명하다.a
# 유발시키다.v
# 유발하다.v
# 유보.n
# 유보하다.v
# 유사하다.a
# 유소년.n
# 유아.n
# 유아어.n
# 유익하다.a
# 유입.n
# 유적.n
# 유적지.n
# 유죄.n
# 유지.n
# 유지되다.v
# 유지하다.v
# 유치하다.v
# 유통.n
# 유형.n
# 유효하다.a
# 육.n
# 육개.n
# 육군.n
# 육군성.n
# 육로.n
# 육상.n
# 육십.n
# 육체.n
# -으로.j
# 은밀하다.a
# -을.j
# 음모.n
# 음미하다.v
# 음식.n
# 음악.n
# 음영.n
# 응답하다.v
# 응수하다.v
# 응시하다.v
# 응용.n
# 응용되다.v
# 응찰.n
# 응하다.v
# -의.j
# 의견.n
# 의견_차이.n
# 의견_충돌.n
# 의도.n
# 의도되다.v
# 의도하다.v
# 의료.n
# 의류.n
# 의무.n
# 의문.n
# 의문시되다.v
# 의미.n
# 의미하다.v
# 의사.n
# 의심.n
# 의심되다.v
# 의심받다.v
# 의심스럽다.a
# 의심의_여지.n
# 의심하다.v
# 의약부.n
# 의약품.n
# 의욕적.n
# 의원.n
# 의의.n
# 의장님.n
# 의정서.n
# 의존.n
# 의존도.n
# 의존하다.v
# 의지.n
# 의지하다.v
# 의하다.v
# 의학.n
# 의학적.n
# 의혹.n
# 이.n
# 이교.n
# 이기다.v
# 이끌다.v
# 이나라.n
# 이년.n
# 이동되다.v
# 이동식.n
# 이동하다.v
# 이들.n
# 이라크.n
# 이란.n
# 이란제.n
# 이래.n
# 이론.n
# 이루다.v
# 이루어지다.v
# 이륙.n
# 이르다.a
# 이름.n
# 이름지.n
# 이목.n
# 이방인.n
# 이번.n
# 이번주.n
# 이별.n
# 이사.n
# 이사오.n
# 이상.n
# 이상하다.a
# 이섬.n
# 이슈.n
# 이야기.n
# 이야기하다.v
# 이어지다.v
# 이외.n
# 이용.n
# 이용되다.v
# 이용하다.v
# 이웃.n
# 이웃하다.v
# 이유.n
# 이익.n
# 이전.n
# 이전되다.v
# 이전하다.v
# 이제.n
# 이제와서.ad
# 이주.n
# 이주하다.v
# 이중용.n
# 이츠카이치카이도.n
# 이탈리아.n
# 이탈리아인.n
# 이틀.n
# 이해.n
# 이해되다.v
# 이해력.n
# 이해하다.a
# 이해하다.v
# 이행.n
# 이행하다.v
# 이혼.n
# 이후.n
# 익사하다.v
# 인간.n
# 인격.n
# 인구.n
# 인근.n
# 인근_지역.n
# 인기.n
# 인도.n
# 인도되다.v
# 인도하다.v
# 인력.n
# 인물.n
# 인상.n
# 인성.n
# 인솔하다.v
# 인쇄하다.v
# 인수.n
# 인식하다.v
# 인용하다.v
# 인원.n
# 인적.n
# 인접_지역.n
# 인접하다.v
# 인정하다.v
# 인종.n
# 인종이.n
# 인지도.n
# 인파.n
# 인품.n
# 인하.n
# 일.n
# 일관되다.v
# 일다.v
# 일단.n
# 일당.n
# 일대.n
# 일련.n
# 일류.n
# 일반.n
# 일반적.n
# 일본.n
# 일부.n
# 일소하다.v
# 일시적_중단.n
# 일어나다.v
# 일어서다.v
# 일으키다.v
# 일정.n
# 일종.n
# 일치.n
# 일치되다.v
# 일치하다.v
# 일컫다.v
# 일하다.v
# 일환.n
# 읽다.v
# 잃다.v
# 임계.n
# 임무.n
# 입.n
# 입구.n
# 입다.v
# 입력되다.v
# 입법_기관.n
# 입법기관.n
# 입법자들.n
# 입속.n
# 입수하다.v
# 입원하다.v
# 입장.n
# 입증.n
# 입증되다.v
# 입증하다.v
# 입학하다.v
# 입히다.v
# 잇다.v
# 잇따르다.v
# 있다.a
# 있다.v
# 잊다.v
# 자.n
# 자객.n
# 자국.n
# 자극.n
# 자극하다.v
# 자금.n
# 자녀.n
# 자라다.v
# 자랑.n
# 자료.n
# 자르다.v
# 자리.n
# 자리잡다.v
# 자매여.n
# 자명하다.a
# 자백하다.v
# 자본.n
# 자부심.n
# 자분천.n
# 자산.n
# 자살.n
# 자세.n
# 자손.n
# 자신.n
# 자신감.n
# 자원.n
# 자원하다.v
# 자유.n
# 자재.n
# 자행하다.v
# 작가.n
# 작년.n
# 작다.a
# 작물.n
# 작업.n
# 작업자.n
# 작업자들.n
# 작업장.n
# 작업하다.v
# 작용제.n
# 작용제들.n
# 작전.n
# 작품.n
# 잔.n
# 잔량.n
# 잔소리를_듣다.v
# 잘못.n
# 잘못되다.v
# 잘못된_방향으로_나가게_하다.v
# 잘하다.v
# 잠기다.v
# 잠자코.ad
# 잠재력.n
# 잡다.v
# 잡무.n
# 잡아당기다.v
# 잡지.n
# 장.n
# 장관.n
# 장군.n
# 장들.n
# 장마.n
# 장면.n
# 장벽.n
# 장비.n
# 장소.n
# 장수.n
# 장식되다.v
# 장악하다.v
# 장애.n
# 장애인.n
# 장착하다.v
# 장치.n
# 재가공.n
# 재개되다.v
# 재개하다.v
# 재건되다.v
# 재고.n
# 재고수.n
# 재난.n
# 재능.n
# 재료.n
# 재미.n
# 재미있다.a
# 재빠르다.a
# 재산.n
# 재생되다.v
# 재심하다.v
# 재잘거리다.v
# 재처리하다.v
# 재치.n
# 재판.n
# 재판하다.v
# 재편하다.v
# 재해.n
# 재확인하다.v
# 쟁취하다.v
# 저급.n
# 저녁.n
# 저물다.v
# 저버리다.v
# 저어.n
# 저자.n
# 저장.n
# 저장되다.v
# 저장소.n
# 저장하다.v
# 저택.n
# 저편.n
# 저항.n
# 저항하다.v
# 적다.a
# 적당하다.a
# 적발하다.v
# 적용.n
# 적용되다.v
# 적용하다.v
# 적재되다.v
# 적재하다.v
# 적절하다.a
# 적하물.n
# 적합하다.a
# 전.n
# 전개.n
# 전국.n
# 전기.n
# 전념하다.v
# 전달되다.v
# 전략.n
# 전략적.n
# 전력.n
# 전문.n
# 전문_지식.n
# 전문가.n
# 전문지식.n
# 전복.n
# 전복되다.v
# 전복시키다.v
# 전사.n
# 전성기.n
# 전술하다.v
# 전역.n
# 전용.n
# 전장.n
# 전쟁.n
# 전제.n
# 전진하다.v
# 전차.n
# 전체.n
# 전체적.n
# 전통.n
# 전통적.n
# 전투.n
# 전투력.n
# 전표.n
# 전하는_바에_의하다.mwe
# 전하다.v
# 전학시키다.v
# 전해지는_바에_의하다.mwe
# 전해지다.v
# 전해진_바에_의하다.mwe
# 전혀.ad
# 전화.n
# 전화하다.v
# 전환.n
# 전환기.n
# 전환되다.v
# 전환시키다.v
# 전환하다.v
# 절.n
# 절대.n
# 절도.n
# 절반.n
# 절벽.n
# 절차.n
# 젊다.a
# 젊은이.n
# 점.n
# 점검.n
# 점검하다.v
# 점보.n
# 점유율.n
# 접경.n
# 접근.n
# 접근_방식.n
# 접근하다.v
# 접속하다.v
# 접수하다.v
# 접어들다.v
# 접촉.n
# 접하다.v
# 정교하다.a
# 정권.n
# 정기.n
# 정기적.n
# 정당화시키다.v
# 정당화하다.v
# 정도.n
# 정면.n
# 정문.n
# 정밀조사.n
# 정박하다.v
# 정보.n
# 정보통.n
# 정복.n
# 정복하다.v
# 정부.n
# 정비.n
# 정상.n
# 정세.n
# 정오.n
# 정원.n
# 정유.n
# 정의.n
# 정의하다.v
# 정장.n
# 정지하다.v
# 정착.n
# 정착자들.n
# 정착지.n
# 정착하다.v
# 정책.n
# 정체성.n
# 정치인.n
# 정하다.v
# 정형외.n
# 정확성.n
# 정확하다.a
# 젖다.v
# 젖어들다.v
# 제거.n
# 제거되다.v
# 제거하다.v
# 제공.n
# 제공되다.v
# 제공하다.v
# 제국.n
# 제기하다.v
# 제도.n
# 제목.n
# 제물.n
# 제시하다.v
# 제안.n
# 제안되다.v
# 제안하다.v
# 제외하다.v
# 제자.n
# 제재.n
# 제조.n
# 제조되다.v
# 제조업.n
# 제조자.n
# 제조하다.v
# 제지하다.v
# 제창하다.v
# 제출.n
# 제출되다.v
# 제출하다.v
# 제품.n
# 제한되다.v
# 제한하다.v
# 제휴.n
# 조건.n
# 조국.n
# 조규.n
# 조금.n
# 조금씩.n
# 조달.n
# 조달자.n
# 조롱당하다.v
# 조립.n
# 조립되다.v
# 조립하다.v
# 조망하다.v
# 조바심.n
# 조사.n
# 조사관.n
# 조사관들.n
# 조사되다.v
# 조사하다.v
# 조상.n
# 조성되다.v
# 조약.n
# 조언하다.v
# 조용하다.a
# 조인국.n
# 조정이혼하다.v
# 조정하다.v
# 조종사.n
# 조종하다.v
# 조직.n
# 조직되다.v
# 조직하다.v
# 조짐.n
# 조처하다.v
# 조치.n
# 조항.n
# 족장.n
# 존경.n
# 존재.n
# 존재성.n
# 존재하다.v
# 존재함.n
# 존중되다.v
# 졸업생.n
# 졸졸.n
# 좁다.a
# 종.n
# 종들.n
# 종료.n
# 종료되다.v
# 종료시키다.v
# 종류.n
# 종말.n
# 종말론적.n
# 종사자.n
# 종사하다.v
# 종식.n
# 종식시키다.v
# 종업원.n
# 종전.n
# 종족.n
# 종종.ad
# 종주국.n
# 종지.n
# 종지기.n
# 종지기들.n
# 종탑.n
# 종합하다.v
# 좋다.a
# 좋아하다.v
# 좌우.n
# 좌절되다.v
# 좌절시키다.v
# 좌파.n
# 죄.n
# 죄송하다.a
# 주.n
# 주가.n
# 주거.n
# 주기.n
# 주년.n
# 주다.v
# 주도되다.v
# 주도하다.v
# 주되다.a
# 주들.n
# 주로.ad
# 주말.n
# 주머니.n
# 주목받다.v
# 주목하다.v
# 주민.n
# 주방놀이.n
# 주변.n
# 주술선.n
# 주시당하다.v
# 주시하다.v
# 주요.n
# 주의.n
# 주의적.n
# 주의하다.v
# 주인.n
# 주일.n
# 주장.n
# 주장되다.v
# 주장에_의하다.mwe
# 주장하다.v
# 주저앉다.v
# 주제.n
# 주지하다.v
# 주차.n
# 주차장.n
# 주차하다.v
# 주창자.n
# 주택.n
# 주황.n
# 죽다.v
# 죽음.n
# 죽이다.v
# 준비.n
# 준비되다.v
# 준비하다.v
# 준수.n
# 준수하다.a
# 준수하다.v
# 줄다.v
# 줄어들다.v
# 줄이다.v
# 줄짓다.v
# 중.n
# 중국.n
# 중국인.n
# 중단되다.v
# 중단시키다.v
# 중단하다.v
# 중대.n
# 중량.n
# 중무장하다.v
# 중반.n
# 중상.n
# 중시.n
# 중시하다.v
# 중심.n
# 중심가.n
# 중심부.n
# 중앙.n
# 중요.n
# 중요성.n
# 중요하다.a
# 중유.n
# 중점.n
# 중증.n
# 중지하다.v
# 즐겁게_뛰놀다.v
# 즐겁다.a
# 즐기다.v
# 증가.n
# 증가되다.v
# 증가시키다.v
# 증가하다.v
# 증거.n
# 증대.n
# 증명.n
# 증명되다.v
# 증명하다.v
# 증상.n
# 증식로.n
# 증언.n
# 증여.n
# 증오하다.v
# 증진시키다.v
# 지갑.n
# 지구.n
# 지구상.n
# 지금.n
# 지나가다.v
# 지나다.v
# 지난주.n
# 지난해.n
# 지니다.v
# 지대.n
# 지도.n
# 지도자.n
# 지뢰.n
# 지리적.n
# 지명되다.v
# 지명하다.v
# 지방.n
# 지배.n
# 지배하다.v
# 지불.n
# 지불하다.v
# 지붕.n
# 지사.n
# 지속적.n
# 지시되다.v
# 지식.n
# 지어주다.v
# 지어지다.v
# 지역.n
# 지역민들.n
# 지역적.n
# 지연되다.v
# 지연시키다.v
# 지원.n
# 지원받다.v
# 지원책.n
# 지원하다.v
# 지인.n
# 지적하다.v
# 지점.n
# 지정.n
# 지정되다.v
# 지정하다.v
# 지주.n
# 지지.n
# 지지하다.v
# 지진.n
# 지참하다.v
# 지치다.v
# 지키다.v
# 지하.n
# 지하철.n
# 지휘.n
# 지휘관.n
# 지휘자.n
# 지휘하다.v
# 직면하다.v
# 직무.n
# 직상승.n
# 직업.n
# 직업이_없다.a
# 직원.n
# 직전.n
# 직후.n
# 진보되다.v
# 진술.n
# 진술하다.v
# 진심.n
# 진열.n
# 진열되다.v
# 진일보.n
# 진입하다.v
# 진전.n
# 진정되다.v
# 진정하다.a
# 진정하다.v
# 진짜.n
# 진척시키다.v
# 진출하다.v
# 진행.n
# 진행되다.v
# 진행하다.v
# 진화.n
# 질리다.a
# 질리다.v
# 질문.n
# 질문받다.v
# 질병.n
# 질책_받다.v
# 질책하다.v
# 집.n
# 집권하다.v
# 집념.n
# 집단.n
# 집들.n
# 집안.n
# 집중하다.v
# 집합장.n
# 집행하다.v
# 집회.n
# 짓다.v
# 징집하다.v
# 징후.n
# 짧다.a
# 쪽.n
# 쭈그리다.v
# 찌그러뜨리다.v
# 찜찜하다.a
# 차.n
# 차관.n
# 차도.n
# 차들.n
# 차량.n
# 차례.n
# 차별.n
# 차분하다.a
# 차이.n
# 착각하다.v
# 착공.n
# 착수하다.v
# 찬성하다.v
# 찬양하다.v
# 참.n
# 참가자.n
# 참견하다.v
# 참고하다.v
# 참모.n
# 참배하다.v
# 참석률.n
# 참석하다.v
# 참여.n
# 참여시키다.v
# 참여자.n
# 참여하다.v
# 참조.n
# 창.n
# 창립.n
# 창문.n
# 창밖.n
# 창설하다.v
# 창의성.n
# 창작하다.v
# 창호지.n
# 찾다.v
# 찾아가다.v
# 찾아내다.v
# 찾아주다.v
# 채소.n
# 채우다.v
# 채택되다.v
# 채택하다.v
# 책.n
# 책들.n
# 책임.n
# 책자.n
# 처리하다.v
# 처벌.n
# 처벌하다.v
# 처음.n
# 처지다.v
# 처형.n
# 처형되다.v
# 척하다.a
# 천년.n
# 천연.n
# 천왕.n
# 천장.n
# 천정.n
# 천톤.n
# 천황.n
# 철.n
# 철거.n
# 철도.n
# 철로.n
# 철수.n
# 철수되다.v
# 철수하다.v
# 철회하다.v
# 첨부하다.v
# 첩보.n
# 첫째.n
# 청구.n
# 청색.n
# 체결되다.v
# 체계.n
# 체류.n
# 체육.n
# 체인점.n
# 체제.n
# 체포되다.v
# 체포하다.v
# 체험.n
# 쳐다보다.v
# 초.n
# 초과하다.v
# 초기.n
# 초대하다.v
# 초반.n
# 초보자.n
# 초안.n
# 초안하다.v
# 초원.n
# 초점.n
# 초조하다.a
# 초청_받다.v
# 초청하다.v
# 촉구하다.v
# 촉발시키다.v
# 총.n
# 총각.n
# 총격전.n
# 총경.n
# 총리.n
# 총살되다.v
# 총재.n
# 총탄.n
# 총합에_이르다.v
# 총회.n
# 최고.n
# 최근.n
# 최단.n
# 최대.n
# 최상.n
# 최선.n
# 최소.n
# 최소한.n
# 최신.n
# 최악.n
# 최저.n
# 최초.n
# 최후.n
# 추가.n
# 추가적.n
# 추구.n
# 추구하다.v
# 추리.n
# 추리다.v
# 추방되다.v
# 추방하다.v
# 추적하다.v
# 추정되다.v
# 추정치.n
# 추정치들.n
# 추정하다.v
# 추진.n
# 추진되다.v
# 추진하다.v
# 추출하다.v
# 추측.n
# 추행.n
# 축제.n
# 축축하다.a
# 축출.n
# 축출당하다.v
# 축출하다.v
# 축하받다.v
# 출발하다.v
# 출산.n
# 출생하다.v
# 출석률.n
# 출신.n
# 출연하다.v
# 출장.n
# 출처.n
# 출퇴근_시간.n
# 출현하다.v
# 춤추다.v
# 충격적.n
# 충돌.n
# 충돌하다.v
# 충분하다.a
# 취급하다.v
# 취득률.n
# 취득하다.v
# 취사.n
# 취소하다.v
# 취약감.n
# 취약하다.a
# 취하다.v
# 취하하다.v
# 측근.n
# 측정되다.v
# 층.n
# 치다.v
# 치료.n
# 치료_가능하다.a
# 치료제.n
# 치루다.v
# 치사.n
# 치안.n
# 칙령.n
# 친.n
# 친구.n
# 친근하다.a
# 친족.n
# 친척.n
# 친하다.a
# 침략.n
# 침울하다.a
# 침체되다.v
# 침투.n
# 침해.n
# 침해하다.v
# 칭송을_받다.v
# 카니발.n
# 카락.n
# 카르텔.n
# 캐나다.n
# 커.n
# 커다랗다.a
# 커버하다.v
# 커지다.v
# 커플.n
# 커피.n
# 컨설턴트.n
# 컬렉션.n
# 컴퓨터.n
# 컵.n
# 코멘트.n
# 퀴즈.n
# 크다.a
# 크리스천.n
# 크리스천들.n
# 클럽.n
# 큼직하다.a
# 키스하다.v
# 키오스크.n
# 킬로그램.n
# 킬로미터.n
# 타격.n
# 타다.v
# 타운.n
# 타워.n
# 타이핑.n
# 탁월하다.a
# 탄.n
# 탄도.n
# 탄도_미사일.n
# 탄도미사일.n
# 탄두.n
# 탄생하다.v
# 탄식하다.v
# 탄약.n
# 탈락하다.v
# 탈취하다.v
# 탈퇴.n
# 탈퇴하다.v
# 탐지되다.v
# 탐지하다.v
# 탐험하다.v
# 탑.n
# 탓.n
# 태도.n
# 태어나다.v
# 태우다.v
# 태초.n
# 택시.n
# 탱크.n
# 터널.n
# 터미널.n
# 테러.n
# 테러리스트.n
# 테러리스트들.n
# 테러리즘.n
# 텐트.n
# 토대.n
# 토로하다.v
# 토론하다.v
# 토요일.n
# 토의하다.v
# 토지.n
# 토착민.n
# 토착민들.n
# 톤.n
# 통.n
# 통감하다.v
# 통과하다.v
# 통들.n
# 통보받다.v
# 통보하다.v
# 통상적.n
# 통신.n
# 통신사.n
# 통용되다.v
# 통제.n
# 통제되다.v
# 통제법.n
# 통제하다.v
# 통증.n
# 통지.n
# 통지하다.v
# 통치.n
# 통치자.n
# 통치하다.v
# 통하다.v
# 통합하다.v
# 투쟁.n
# 투하.n
# 투하하다.v
# 트럭.n
# 트롤링.n
# 특성.n
# 특수하다.a
# 특이하다.a
# 특정.n
# 특징.n
# 특징짓다.v
# 특허.n
# 특허권.n
# 튼튼하다.a
# 틀리다.v
# 틀림없다.a
# 팀.n
# 파견하다.v
# 파괴.n
# 파괴되다.v
# 파괴하다.v
# 파다.v
# 파벌.n
# 파손시키다.v
# 파악하다.v
# 파운드.n
# 파트너.n
# 파티.n
# 판결.n
# 판단되다.v
# 판례.n
# 판매.n
# 판매・.n
# 판매되다.v
# 판매액.n
# 판매원.n
# 판매하다.v
# 팔.n
# 팔다.v
# 팔리다.v
# 패배.n
# 패배하다.v
# 패키지.n
# 패턴.n
# 패해자들.n
# 팽개치다.v
# 퍼뜨리다.v
# 퍼지다.v
# 페이스.n
# 편.n
# 편견.n
# 편종.n
# 편지.n
# 펼쳐지다.v
# 평가.n
# 평가하다.v
# 평균.n
# 평범하다.a
# 평안.n
# 폐기.n
# 폐기되다.v
# 폐쇄감.n
# 폐지되다.v
# 포.n
# 포기하다.v
# 포병.n
# 포스트.n
# 포위당하다.v
# 포위하다.v
# 포장하다.v
# 포탄.n
# 포함.n
# 포함되다.v
# 포함하다.v
# 폭격.n
# 폭격하다.v
# 폭로.n
# 폭로되다.v
# 폭로하다.v
# 폭발물.n
# 폭발성.n
# 폭소.n
# 폭약.n
# 폭탄.n
# 폭포.n
# 폭포일부.n
# 폭풍.n
# 표.n
# 표면.n
# 표면상.n
# 표명하다.v
# 표시.n
# 표적.n
# 표현하다.v
# 푸념.n
# 풀다.v
# 풀려나다.v
# 품목.n
# 풍경.n
# 풍기다.v
# 풍부하다.a
# 풍성하다.a
# 풍족하다.a
# 프랑스.n
# 프로그램.n
# 프로세스.n
# 프로젝트.n
# 플라스틱_폭탄.n
# 플루토늄.n
# 플루토니움.n
# 피난소.n
# 피난처.n
# 피난하다.v
# 피부.n
# 피살되다.v
# 피우다.v
# 피칭.n
# 피크.n
# 피트.n
# 피하다.v
# 필기물.n
# 필수.n
# 필수품.n
# 필요.n
# 필요성.n
# 필요하다.a
# 필적하다.v
# 하다.a
# 하다.v
# 하루.n
# 하부.n
# 하안.n
# 하얗다.a
# 하와이제.n
# 하우스.n
# 하원.n
# 학교.n
# 학교_선생.n
# 학교상.n
# 학대_받다.v
# 학문.n
# 학살.n
# 학살하다.v
# 학생.n
# 학습.n
# 학습하다.v
# 학습회.n
# 학업.n
# 학자.n
# 학파.n
# 한계치.n
# 한담.n
# 한반도.n
# 한숨짓다.v
# 한심하다.a
# 한쪽.n
# 한창.n
# 한탄하다.v
# 한편.n
# 할_말을_잃다.a
# 할부금.n
# 할아버지.n
# 함께.ad
# 함께하다.v
# 함락하다.v
# 함수.n
# 합격.n
# 합계.n
# 합류.n
# 합류하다.v
# 합리화하다.v
# 합법적.n
# 합숙.n
# 합의.n
# 합의하다.v
# 항공.n
# 항공기.n
# 항구.n
# 항로.n
# 항상.a
# 해.n
# 해결되다.v
# 해결책.n
# 해결하다.v
# 해고시키다.v
# 해군.n
# 해당.n
# 해당_단체.n
# 해당하다.v
# 해방시키다.v
# 해변.n
# 해보다.v
# 해상.n
# 해설.n
# 해소하다.v
# 해안.n
# 해인.n
# 해적.n
# 해제.n
# 해제되다.v
# 해제하다.v
# 해질녘.n
# 해체.n
# 해체되다.v
# 해체하다.v
# 핵.n
# 핵_무기.n
# 핵무기.n
# 핵심.n
# 핵원자.n
# 핵원조.n
# 핵전력.n
# 핵폭탄.n
# 햇볕.n
# 행동.n
# 행동하다.v
# 행렬.n
# 행복하다.a
# 행사.n
# 행운.n
# 행위.n
# 행진하다.v
# 행하다.v
# 향기를 내다.v
# 향상.n
# 향상되다.v
# 향상시키다.v
# 향유되다.v
# 향하다.v
# 향후.n
# 허덕이다.v
# 허락하다.v
# 허리.n
# 허물.n
# 허용.n
# 허용되다.v
# 허용하다.v
# 허위.n
# 헌신하다.v
# 헌터.n
# 헤어지다.v
# 헥타르.n
# 혁명.n
# 혁명가.n
# 현・.n
# 현금.n
# 현대.n
# 현대식.n
# 현대화.n
# 현상.n
# 현실.n
# 현역.n
# 현장.n
# 현재.n
# 현지.n
# 혈연.n
# 혐오.n
# 혐의.n
# 혐의를_받다.v
# 협곡.n
# 협동.n
# 협력.n
# 협력자.n
# 협력하다.v
# 협상.n
# 협상하다.v
# 협약.n
# 협의하다.v
# 협정.n
# 협조.n
# 형.n
# 형성.n
# 형성되다.v
# 형성하다.v
# 형장.n
# 형제.n
# 형제단.n
# 형제여.n
# 형태.n
# 혜택.n
# 호감.n
# 호리호리하다.a
# 호면.n
# 호소하다.v
# 호수.n
# 호텔.n
# 혼나다.v
# 혼란.n
# 혼합.n
# 혼합되다.v
# 홀.n
# 화.n
# 화나다.v
# 화내다.v
# 화물선.n
# 화산.n
# 화살n.Aiming
# 화학.n
# 화학_무기.n
# 화학무기.n
# 화학전.n
# 확대.n
# 확대되다.v
# 확대하다.v
# 확립.n
# 확립하다.v
# 확보.n
# 확보하다.v
# 확산.n
# 확산시키다.v
# 확신하다.v
# 확실하다.a
# 확인.n
# 확인되다.v
# 확인하다.v
# 확장.n
# 확장되다.v
# 확장하다.v
# 확증하다.v
# 환경.n
# 환영.n
# 환호.n
# 활기.n
# 활동.n
# 활동적이다.a
# 활력.n
# 활발하다.a
# 활성화하다.v
# 활용.n
# 활주로.n
# 황제.n
# 황폐.n
# 회.n
# 회개.n
# 회담.n
# 회담하다.v
# 회보.n
# 회복.n
# 회복하다.v
# 회사.n
# 회생.n
# 회신.n
# 회원.n
# 회원국.n
# 회의.n
# 회의실.n
# 회의하다.v
# 회장.n
# 회피.n
# 획득.n
# 획득되다.v
# 획득하다.v
# 효과.n
# 효과적.n
# 후.n
# 후계자.n
# 후렴.n
# 후반.n
# 후방.n
# 후속.n
# 후예.n
# 후하다.a
# 후회되다.v
# 후회하다.v
# 훈련.n
# 훈련_받다.v
# 훈련되다.v
# 훈련시키다.v
# 훈련하다.v
# 훌륭하다.a
# 훔치다.v
# 휘말리다.v
# 휴대용.n
# 휴식.n
# 흐르다.v
# 흔들다.v
# 흔들리다.v
# 흔적.n
# 흘러가다.v
# 흘러나가다.v
# 흡수되다.v
# 흡연.n
# 흥미롭다.a
# 흥분.n
# 흩어지다.v
# 희다.a
# 희망.n
# 희망하다.v
# 희생자.n
# 히나마쓰리.n
# 힘.n
# 힘들다.a
# 힘쓰다.v
# # of lus: 4065
# 4065 is indexed to ../resource/info/kfn1.0_lu2idx.json

# %%
def get_frame_idxs_for_lu(lu):
    frames = []
    for luid in lus:
        lu_item = lus[luid]['lexeme']+'.'+lus[luid]['pos']
        frame = lus[luid]['frame']
        if lu_item == lu:
            frame_idx = int(frame2idx[frame])
            frames.append(frame_idx)
    return frames
def gen_lufrmap():    
    lu2idx_file = info_path+'kfn'+str(version)+'_lu2idx.json'
    with open(lu2idx_file, 'r') as f:
        lu2idx = json.load(f)
    idx2lu = dict(zip(lu2idx.values(),lu2idx.keys()))
    lufrmap = {}
    for lu in lu2idx:
        lu_idx = lu2idx[lu]
        frame_idxs = get_frame_idxs_for_lu(lu)
        lufrmap[lu_idx] = frame_idxs
        
    fname = info_path+'kfn'+str(version)+'_lufrmap.json'
    with open(fname, 'w') as f:
        json.dump(lufrmap, f, ensure_ascii=False, indent=4)
    print('# of lus:', len(lu2idx))
    print(len(lufrmap),'is assigned to frame candidates into', fname)
gen_lufrmap()
# Out:
# # of lus: 4065
# 4065 is assigned to frame candidates into ../resource/info/kfn1.0_lufrmap.json
