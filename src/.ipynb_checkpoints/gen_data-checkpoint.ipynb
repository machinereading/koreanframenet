# %%
import json

# %%
version = 1.0
kfn_path = '../resource/'+str(version)
fn_path = '../resource/info/FN17_frame_id.json'
web_path = '../../koreanframenet-web/data/kolu_'+str(version)+'/'

# %%
def load_kfn():
    with open(kfn_path+'/KFN_annotations.json','r') as f:
        kfn = json.load(f)
    return kfn
kfn = load_kfn()

# %%
def load_fn17():
    with open(fn_path,'r') as f:
        fn = json.load(f)
    return fn
fn = load_fn17()
def get_fnid(frame):
    for i in fn:
        if i['frame'] == frame:
            return i['id']

# %%
def make_key(string):
    return string.replace('-', '').upper()
def get_surface_form(target_span, text):
    return text[target_span['begin']:target_span['end']]
def get_fes(denos):
    fes = []
    for deno in denos:
        if deno['role'] == 'ARGUMENT':
            fes.append(deno['obj'])
    return list(set(fes))
    

def gen_lus():
    lus = {}
    lu_items = []
    for i in kfn:
        d = kfn[i]
        lu_items.append(d['lu'])
    lu_items = list(set(lu_items))
    lu_items.sort(key=make_key)
    lu_index = {}
    for i in lu_items:
        lu_index[i] = len(lu_index)+1
    
    for i in kfn:
        annotation_id = int(i)
        d = kfn[i]
        lu = d['lu']
        pos = lu.split('.')[1]
        frame = d['frame']
        text = d['text']
        lexeme = lu.split('.')[0]
        for deno in d['denotations']:
            if deno['role'] == 'TARGET':
                target_span = deno['span']
        surface_form = get_surface_form(target_span, text)
        fid = get_fnid(frame)
        new_fes = get_fes(d['denotations'])
        
        luid = lu_index[lu]
        
        if luid not in lus:
            item = {}
            item['lu'] = lu
            item['pos'] = pos
            item['lexeme'] = lexeme
            item['frame'] = frame
            item['fid'] = int(fid)
            surface_forms = []
            surface_forms.append(surface_form)
            surface_forms = list(set(surface_forms))
            item['surface_forms'] = surface_forms
            annotation_ids = []
            annotation_ids.append(annotation_id)
            annotation_ids = list(set(annotation_ids))
            item['annotation_ids'] = annotation_ids
            lus[luid] = item
        else:
            item = lus[luid]
            surface_forms = item['surface_forms']
            surface_forms.append(surface_form)
            surface_forms = list(set(surface_forms))
            item['surface_forms'] = surface_forms
            annotation_ids = item['annotation_ids']
            annotation_ids.append(annotation_id)
            annotation_ids = list(set(annotation_ids))
            item['annotation_ids'] = annotation_ids
            lus[luid] = item
    with open(kfn_path+'/KFN_lus.json','w') as f:
        json.dump(lus, f, ensure_ascii=False, indent=4)
    print(len(lus), 'lus are saved')
gen_lus()
# Out:
# 5661 lus are saved

# %%
def gen_web_files():
    with open(kfn_path+'/KFN_lus.json','r') as f:
        lus = json.load(f)
    n = 0
    for luid in lus:
        d = lus[luid]
        fname = web_path+luid+'.json'

        lu = d['lu']
        ko_pos = d['pos']
        frameID = d['fid']
        frameName = d['frame']
        lu_id = luid
        
        patterns = []
        for aid in d['annotation_ids']:
            examples = []
            example = {}
            example['denotations'] = kfn[str(aid)]['denotations']
            example['relations'] = kfn[str(aid)]['relations']
            if 'FrameNet' in kfn[str(aid)]['sent_id']:
                example['sent_id'] =  kfn[str(aid)]['sent_id'].split('-')[-1]
            example['lu'] = lu
            example['text'] = kfn[str(aid)]['text']
            examples.append(example)
            
            pattern = {}
            # valence pattern
            pattern['valenceText'] = 'id: '+kfn[str(aid)]['sent_id']
            pattern['examples'] = examples
            patterns.append(pattern)
            
        item = {}
        # origin_lus
        item['en_lus'] = []
        item['ko_lu'] = lu
        item['ko_pos'] = ko_pos
        item['frameID'] = frameID
        item['frameName'] = frameName
        item['lu_id'] = lu_id
        item['patterns'] = patterns
        
        with open(fname, 'w') as f:
            json.dump(item, f, ensure_ascii=False, indent=4)
        n += 1
    print(n, 'files are writed')
    
    lu_items = []
    for i in kfn:
        d = kfn[i]
        lu_items.append(d['lu'])
    lu_items = list(set(lu_items))
    lu_items.sort(key=make_key)

    n=0
    luindex = []
    for i in lu_items:
        n+=1
        item = {}
        item['lu'] = i
        item['pos'] = i.split('.')[1]
        item['id'] = n
        luindex.append(item)
    with open(web_path+'index.json','w') as f:
        json.dump(luindex, f, ensure_ascii=False, indent=4)
        
gen_web_files()
# Out:
# 5661 files are writed
# ['-ㄹ_것이다.a.Certainty', '가게.n.Businesses', '가게.n.Locale_by_use', '가격.n.Commerce_scenario', '가계.n.Kinship', '가공.n.Manufacturing', '가공.n.Processing_materials', '가공되다.v.Ground_up', '가공하다.v.Grinding', '가까워지다.v.Arriving', '가깝다.a.Locative_relation', '가끔.n.Frequency', '가난.n.Wealthiness', '가능성.n.Capability', '가능성.n.Likelihood', '가능성있다.a.Likelihood', '가능하다.a.Capability', '가능하다.a.Existence', '가능하다.a.Likelihood', '가다.v.Arriving', '가다.v.Causation', '가다.v.Locale', '가다.v.Motion', '가다.v.Motion_directional', '가다.v.Operate_vehicle', '가다.v.Self_motion', '가담하다.v.Participation', '가동.n.Using', '가동되다.v.Becoming', '가동되다.v.Using', '가동하다.v.Using', '가득하다.a.Abounding_with', '가라앉다.v.Motion_directional', '가로.n.Direction', '가로막다.v.Intercepting', '가로지르다.v.Motion', '가로채다.v.Intercepting', '가르다.v.Education_teaching', '가르치다.v.Education_teaching', '가리다.v.Evidence', '가만하다.v.Posture', '가문.n.Kinship', '가볍다.a.Position_on_a_scale', '가사.n.Text', '가스.n.Substance', '가슴.n.Body_parts', '가운데.n.Be_subset_of', '가운데.n.Locative_relation', '가운데.n.Partitive', '가운데.n.Temporal_collocation', '가위눌리다.v.State_of_entity', '가을.n.Calendric_unit', '가입하다.v.Becoming_a_member', '가입하다.v.Participation', '가입하다.v.Sign_agreement', '가장.n.Wearing', '가장_아름답다.a.Aesthetics', '가장_우수하다.a.Desirability', '가정.n.Buildings', '가정.n.Medical_professionals', '가정.n.People_by_vocation', '가져가다.v.Bringing', '가져가다.v.Perception_active', '가져오다.v.Bringing', '가져오다.v.Causation', '가져오다.v.Cause_to_amalgamate', '가족.n.Kinship', '가지.n.Part_piece', '가지다.v.Accompaniment', '가지다.v.Becoming', '가지다.v.Bringing', '가지다.v.Capability', '가지다.v.Containing', '가지다.v.Getting', '가지다.v.Have_associated', '가지다.v.Inclusion', '가지다.v.Possession', '가치.n.Deserving', '가치.n.Usefulness', '가치있다.a.Deserving', '가치있다.a.Usefulness', '가치적.n.Usefulness', '각도.n.Distinctiveness', '각성.n.Organization', '각지.n.Locale', '간.n.Locative_relation', '간.n.Temporal_collocation', '간격.n.Frequency', '간결하다.a.Duration_description', '간주되다.v.Awareness', '간주되다.v.Categorization', '간주하다.v.Categorization', '간주하다.v.Communicate_categorization', '간호사.n.Medical_professionals', '갇히다.v.Immobilization', '갈기.n.Body_parts', '갈다.v.Replacing', '갈래.n.Motion', '갈망.n.Desiring', '감각.n.Sensation', '감다.a.Body_movement', '감다.a.Closure', '감동하다.v.Experiencer_focus', '감미롭다.a.Chemical-sense_description', '감사하다.a.Experiencer_focus', '감사하다.a.Judgment', '감사하다.a.Judgment_direct_address', '감사하다.a.Regard', '감성.n.Sensation', '감소.n.Cause_change_of_position_on_a_scale', '감소.n.Change_position_on_a_scale', '감소되다.v.Change_position_on_a_scale', '감소부.n.Cause_change_of_position_on_a_scale', '감소부.n.Project', '감소시키다.v.Cause_change_of_position_on_a_scale', '감소하다.v.Cause_change_of_position_on_a_scale', '감소하다.v.Change_position_on_a_scale', '감시.n.Perception_active', '감시.n.Scrutiny', '감시하다.v.Scrutiny', '감싸다.v.Distributed_position', '감싸다.v.Locative_relation', '감싸다.v.Perception_active', '감안하다.v.Categorization', '감염증.n.Medical_conditions', '감옥.n.Prison', '감정.n.Feeling', '감지하다.v.Intentionally_act', '감지하다.v.Perception_experience', '감찰.n.Inspecting', '감추다.v.Eclipse', '감탄.n.Judgment', '감탄하다.v.Regard', '갑종.n.First_rank', '갔다오다.v.Becoming', '강.n.Natural_features', '강간자.n.Rape', '강간하다.v.Rape', '강력하다.a.Level_of_force_exertion', '강력하다.a.Stimulus_focus', '강렬하다.a.Degree', '강물.n.Natural_features', '강물.n.Substance', '강연회.n.Discussion', '강연회.n.Text', '강자.n.Dominate_competitor', '강제.n.Cause_motion', '강조되다.v.Emphasizing', '강조하다.v.Convey_importance', '강조하다.v.Emphasizing', '강타.n.Attack', '강타하다.v.Impact', '강탈되다.v.Conquering', '강하다.a.Degree', '강화하다.v.Cause_change_of_strength', '강화하다.v.Cause_to_amalgamate', '강화하다.v.Supporting', '갖다.v.Possession', '갖추다.v.Have_associated', '갖추다.v.Inclusion', '갖추다.v.Possession', '갖추다.v.Supply', '같다.a.Appeal', '같다.a.Identicality', '같다.a.Similarity', '같다.a.State_continue', '같다.a.Type', '개.n.Obviousness', '개국.n.Political_locales', '개명하다.v.Name_conferral', '개발.n.Cause_to_make_progress', '개발.n.Progression', '개발되다.v.Cause_to_make_progress', '개발되다.v.Progression', '개발중.n.Cause_to_make_progress', '개발하다.v.Cause_to_make_progress', '개 ...
