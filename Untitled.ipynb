# %%
import koreanframenet

version = 1.2 
kfn = koreanframenet.interface(version=version)

lus = kfn.lus_by_word('입증하다')
print(lus)

lus = kfn.lus_by_frame('Verification')
print(lus)

frames = kfn.frames()
print(len(frames))
print(frames)

annotations = kfn.annotations_by_lu(5566)
print(annotations[4])

trans = kfn.get_trans_by_word('입증하다')
print(trans)

trans = kfn.get_trans(5566)
print(trans)
# Out:
# [{'lu': '입증하다.v', 'frame': 'Statement', 'lu_id': 5565}, {'lu': '입증하다.v', 'frame': 'Verification', 'lu_id': 5566}, {'lu': '입증하다.v', 'frame': 'Evidence', 'lu_id': 5564}]
# [{'lu': '인정받다.v', 'frame': 'Verification', 'lu_id': 5441}, {'lu': '인정시키다.v', 'frame': 'Verification', 'lu_id': 5442}, {'lu': '검증되다.v', 'frame': 'Verification', 'lu_id': 419}, {'lu': '하다.a', 'frame': 'Verification', 'lu_id': 7460}, {'lu': '검증시키다.v', 'frame': 'Verification', 'lu_id': 420}, {'lu': '확인.n', 'frame': 'Verification', 'lu_id': 7782}, {'lu': '검증하다.v', 'frame': 'Verification', 'lu_id': 423}, {'lu': '확인되다.v', 'frame': 'Verification', 'lu_id': 7784}, {'lu': '인증되다.v', 'frame': 'Verification', 'lu_id': 5449}, {'lu': '인증하다.v', 'frame': 'Verification', 'lu_id': 5451}, {'lu': '수첩.n', 'frame': 'Verification', 'lu_id': 4047}, {'lu': '확인하다.v', 'frame': 'Verification', 'lu_id': 7792}, {'lu': '확증되다.v', 'frame': 'Verification', 'lu_id': 7798}, {'lu': '입증.n', 'frame': 'Verification', 'lu_id': 5559}, {'lu': '확증하다.v', 'frame': 'Verification', 'lu_id': 7800}, {'lu': '입증되다.v', 'frame': 'Verification', 'lu_id': 5562}, {'lu': '공증되다.v', 'frame': 'Verification', 'lu_id': 731}, {'lu': '공증하다.v', 'frame': 'Verification', 'lu_id': 733}, {'lu': '입증하다.v', 'frame': 'Verification', 'lu_id': 5566}, {'lu': '인정되다.v', 'frame': 'Verification', 'lu_id': 5439}]
# 809
# ['Abandonment', 'Abounding_with', 'Absorb_heat', 'Abundance', 'Abusing', 'Accompaniment', 'Accomplishment', 'Accoutrements', 'Accuracy', 'Achieving_first', 'Active_substance', 'Activity', 'Activity_done_state', 'Activity_finish', 'Activity_ongoing', 'Activity_pause', 'Activity_prepare', 'Activity_ready_state', 'Activity_resume', 'Activity_start', 'Activity_stop', 'Actually_occurring_entity', 'Addiction', 'Adding_up', 'Adducing', 'Adjacency', 'Adjusting', 'Adopt_selection', 'Aesthetics', 'Affirm_or_deny', 'Age', 'Aggregate', 'Aging', 'Agree_or_refuse_to_act', 'Aiming', 'Alliance', 'Alternatives', 'Amalgamation', 'Amassing', 'Ambient_temperature', 'Ammunition', 'Amounting_to', 'Appeal', 'Apply_heat', 'Appointing', 'Architectural_part', 'Arranging', 'Arrest', 'Arriving', 'Artifact', 'Artificiality', 'Assemble', 'Assessing', 'Assistance', 'Attaching', 'Attack', 'Attempt', 'Attempt_means', 'Attempt_suasion', 'Attending', 'Attention', 'Attributed_information', 'Attributes', 'Avoiding', 'Awareness', 'Be_in_agreement_on_action', 'Be_in_agreement_on_assessment', 'Be_subset_of', 'Bearing_arms', 'Beat_opponent', 'Becoming', 'Becoming_a_member', 'Becoming_attached', 'Becoming_aware', 'Becoming_detached', 'Becoming_dry', 'Becoming_separated', 'Becoming_silent', 'Becoming_visible', 'Behind_the_scenes', 'Being_active', 'Being_at_risk', 'Being_attached', 'Being_born', 'Being_dry', 'Being_employed', 'Being_in_category', 'Being_in_control', 'Being_in_effect', 'Being_in_operation', 'Being_located', 'Being_named', 'Being_necessary', 'Being_obligated', 'Being_operational', 'Being_up_to_it', 'Being_wet', 'Besieging', 'Beyond_compare', 'Billing', 'Biological_area', 'Biological_urge', 'Board_vehicle', 'Body_description_holistic', 'Body_mark', 'Body_movement', 'Body_parts', 'Bond_maturation', 'Borrowing', 'Boundary', 'Bragging', 'Breaking_apart', 'Breaking_off', 'Breathing', 'Bringing', 'Building', 'Building_subparts', 'Buildings', 'Bungling', 'Businesses', 'Calendric_unit', 'Candidness', 'Capability', 'Capacity', 'Cardinal_numbers', 'Carry_goods', 'Catastrophe', 'Categorization', 'Causation', 'Cause_bodily_experience', 'Cause_change', 'Cause_change_of_consistency', 'Cause_change_of_phase', 'Cause_change_of_position_on_a_scale', 'Cause_change_of_strength', 'Cause_expansion', 'Cause_fluidic_motion', 'Cause_harm', 'Cause_impact', 'Cause_motion', 'Cause_temperature_change', 'Cause_to_amalgamate', 'Cause_to_be_dry', 'Cause_to_be_included', 'Cause_to_be_sharp', 'Cause_to_be_wet', 'Cause_to_continue', 'Cause_to_end', 'Cause_to_experience', 'Cause_to_fragment', 'Cause_to_land', 'Cause_to_make_noise', 'Cause_to_make_progress', 'Cause_to_move_in_place', 'Cause_to_perceive', 'Cause_to_resume', 'Cause_to_start', 'Cause_to_wake', 'Ceasing_to_be', 'Certainty', 'Change_direction', 'Change_event_duration', 'Change_event_time', 'Change_of_consistency', 'Change_of_leadership', 'Change_of_phase', 'Change_of_temperature', 'Change_operational_state', 'Change_position_on_a_scale', 'Change_posture', 'Change_tool', 'Chatting', 'Chemical-sense_description', 'Choosing', 'Circumscribed_existence', 'Claim_ownership', 'Closure', 'Clothing', 'Cogitation', 'Cognitive_connection', 'Collaboration', 'Colonization', 'Color', 'Come_down_with', 'Come_into_effect', 'Come_together', 'Coming_to_be', 'Coming_to_believe', 'Coming_up_with', 'Commerce_buy', 'Commerce_pay', 'Commerce_scenario', 'Commerce_sell', 'Commercial_transaction', 'Commitment', 'Committing_crime', 'Communicate_categorization', 'Communication', 'Communication_manner', 'Communication_means', 'Communication_noise', 'Communication_response', 'Commutative_process', 'Compatibility', 'Competition', 'Complaining', 'Completeness', 'Compliance', 'Concessive', 'Conduct', 'Confronting_problem', 'Connecting_architecture', 'Connectors', 'Conquering', 'Contacting', 'Containers', 'Containing', 'Contingency', 'Continued_state_of_affairs', 'Contrition', 'Control', 'Convey_importance', 'Cooking_creation', 'Corporal_punishment', 'Correctness ...
# {'lu': '입증하다.v.Verification', 'text': '한국 축구팬들에게 첫선을 보인 마이클 오언이 세계 최고 골잡이의 명성을 그대로 입증했다.', 'arguments': ['한국 축구팬들에게 첫선을 보인 마이클 오언이 [Inspector]', '세계 최고 골잡이의 명성을 [Unconfirmed_content]', '그대로 [Manner]']}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-e448d491ce7e> in <module>()
#      17 print(annotations[4])
#      18
# ---> 19 trans = kfn.get_trans_by_word('입증하다')
#      20 print(trans)
#      21
#
# /disk/frameBERT/frameBERT/koreanframenet/koreanframenet.py in get_trans_by_word(self, word)
#     113         for lu_item in lus:
#     114             lu, frame, luid = lu_item['lu'],lu_item['frame'],lu_item['lu_id']
# --> 115             trans = kfn_interface.get_trans(luid)
#     116             item = {}
#     117             item['lu'] = lu
#
# /disk/frameBERT/frameBERT/koreanframenet/koreanframenet.py in get_trans(self, luid)
#     104     def get_trans(self, luid):
#     105         luid = str(luid)
# --> 106         trans = self.kfn_lus[luid]['edef']
#     107         return trans
#     108
#
# KeyError: 'edef'
